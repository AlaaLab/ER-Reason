# %%
## Predict what patients are readmitted for using past medical history (using final diagnosis tab col)

# %%
import pandas as pd
pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_colwidth', None)  # Set max column width to None
pd.set_option('display.width', None)  # Set width to None

# %%
df = pd.read_csv('filtered_final_dataset.csv')

# %%
df.shape, df.columns
# Out:
# ((3984, 43),
#  Index(['Unnamed: 0', 'Unnamed: 0.1', 'patientdurablekey', 'encounterkey',
#         'ArrivalDateKey', 'DepartureDateKeyValue', 'DepartureDateKey',
#         'DispositionDateKeyValue', 'primarychiefcomplaintname',
#         'primaryeddiagnosisname', 'sex', 'birthdate', 'firstrace',
#         'preferredlanguage', 'highestlevelofeducation', 'maritalstatus', 'Age',
#         'Discharge_Summary_Date', 'Discharge_Summary_Note_Key',
#         'Progress_Note_Date', 'Progress_Note_Key', 'HP_Note_Date',
#         'HP_Note_Key', 'Echo_Date', 'Echo_Key', 'Imaging_Date', 'Imaging_Key',
#         'Consult_Date', 'Consult_Key', 'ED_Provider_Notes_Date',
#         'ED_Provider_Notes_Key', 'ECG_Date', 'ECG_Key',
#         'Discharge_Summary_Text', 'Progress_Note_Text', 'HP_Note_Text',
#         'Echo_Text', 'Imaging_Text', 'Consult_Text', 'ECG_Text',
#         'ED_Provider_Notes_Text', 'One_Sentence_Extracted', 'note_count'],
#        dtype='object'))

# %%
df['primaryeddiagnosisname'].nunique()
# Out:
# 1554

# %%
for val in df['primaryeddiagnosisname'].unique():
    print(val)
# Out:
# CAD in native artery
# Vesicular rash
# SBO (small bowel obstruction) (CMS code)
# Gastroduodenitis
# Nausea vomiting and diarrhea
# Abdominal pain
# Acute abdominal pain
# Chronic cholecystitis
# Generalized abdominal pain
# Cellulitis, unspecified cellulitis site
# Cholelithiasis without cholecystitis
# Complicated UTI (urinary tract infection)
# Abdominal pain, right lower quadrant
# Strangulated hernia of abdominal wall
# Generalized weakness
# Chronic pancreatitis, unspecified pancreatitis type (CMS code)
# Sepsis, due to unspecified organism, unspecified whether acute organ dysfunction present (CMS code)
# Diverticulitis of colon with perforation
# Altered mental status, unspecified altered mental status type
# Urinary retention
# Chronic abdominal pain
# Lower abdominal pain
# Abdominal pain, right upper quadrant
# Obstructive hyperbilirubinemia (CMS code)
# Thrombosis of ovarian vein
# Chest pain, unspecified type
# Pericarditis with effusion
# Pyelonephritis
# Abdominal pain, left lower quadrant
# Diverticulitis
# Colostomy in place (CMS code)
# Nausea and vomiting in adult
# Retroperitoneal liposarcoma (CMS code)
# Abdominal pain, epigastric
# Symptomatic cholelithiasis
# Hyperkalemia
# Encounter for pre-transplant evaluation for chronic liver disease
# Vomiting in adult
# Post-operative pain
# Abdominal pain, unspecified abdominal location
# Periumbilical abdominal pain
# Bladder diverticulum
# Portal vein thrombosis
# Crohn's colitis, other complication (CMS code)
# Peritoneal mesothelioma (CMS code)
# Appendicitis with peritonitis
# ESRD (end stage renal disease) (CMS code)
# Other ascites
# Other acute pancreatitis, unspecified complication status
# Left ureteral stone
# Acute cholecystitis
# Acute appendicitis, unspecified acute appendicitis type
# Decompensated hepatic cirrhosis (CMS code)
# SMAS (superior mesenteric artery syndrome) (CMS code)
# Cerebral arterial aneurysm
# Neck mass
# Pancreatitis, necrotizing
# Anemia, unspecified type
# Pseudoaneurysm of femoral artery (CMS code)
# Choledocholithiasis
# Diarrhea, unspecified type
# Elevated LFTs
# Alcohol withdrawal, uncomplicated (CMS code)
# Nausea and vomiting, unspecified vomiting type
# Cancer associated pain
# Vomiting, unspecified vomiting type, unspecified whether nausea present
# Hypercarbia
# Nephrolithiasis
# Chronic pancreatitis due to acute alcohol intoxication (CMS code)
# Chronic GERD
# Acute pulmonary embolism, unspecified pulmonary embolism type, unspecified whether acute cor pulmonale present (CMS code)
# Gastroparesis
# Complains of low back pain
# Partial small bowel obstruction (CMS code)
# Hydronephrosis, unspecified hydronephrosis type
# Abdominal aortic aneurysm (AAA) without rupture, unspecified part (CMS code)
# Choledocholithiasis with acute cholecystitis
# Epigastric pain
# Pain of left lower extremity
# Cellulitis of abdominal wall
# Abdominal wall cellulitis
# Ulcerative colitis with complication, unspecified location (CMS code)
# Constipation, unspecified constipation type
# H/O hernia repair
# History of renal transplant
# Upper GI bleed
# Colitis
# Liver abscess
# Chronic pancreatitis due to chronic alcoholism (CMS code)
# Prostate abscess
# Abdominal pain, left upper quadrant
# Melena
# Kidney stone
# COVID-19
# RUQ abdominal pain
# Endometriosis
# Fever, unspecified fever cause
# Enteritis
# Acute on chronic pancreatitis (CMS code)
# Periumbilical hernia
# Pelvic fluid collection
# Mass of thoracic vertebra
# Crohn's disease of colon, unspecified complication (CMS code)
# Malignant neoplasm of ovary, unspecified laterality (CMS code)
# Esophageal varices without bleeding, unspecified esophageal varices type (CMS code)
# Cellulitis of left foot
# Diffuse large B-cell lymphoma, unspecified body region (CMS code)
# Hyponatremia
# LUQ abdominal pain
# Mesenteric vein thrombosis (CMS code)
# Acute alcoholic hepatitis (CMS code)
# Right sided abdominal pain
# Thrombocytopenia (CMS code)
# AKI (acute kidney injury) (CMS code)
# Acute on chronic heart failure, unspecified heart failure type (CMS code)
# Malignant neoplasm of endocervix (CMS code)
# Jaundice
# Liver damage
# Pneumonia due to infectious organism, unspecified laterality, unspecified part of lung
# Penile pain
# Spontaneous bacterial peritonitis (CMS code)
# Bronchiectasis with acute exacerbation (CMS code)
# Omental infarction (CMS code)
# Pneumonia of right lung due to infectious organism, unspecified part of lung
# Hypoxia
# UTI (urinary tract infection), uncomplicated
# Foreign body ingestion, initial encounter
# Crohn's disease of colon with complication (CMS code)
# Abdominal distension
# Ileus (CMS code)
# Hypomagnesemia
# Nausea and vomiting, intractability of vomiting not specified, unspecified vomiting type
# Intraabdominal fluid collection
# Substance use
# Malnutrition due to starvation (CMS code)
# Liver lesion
# PID (acute pelvic inflammatory disease)
# Ureteral stone
# Inguinal hernia with irreducibility
# Cancer, metastatic to liver (CMS code)
# Dementia with behavioral disturbance (CMS code)
# Colostomy prolapse (CMS code)
# Incarcerated hernia
# Large bowel obstruction (CMS code)
# Squamous cell carcinoma of unknown origin
# Malignant neoplasm of sigmoid colon (CMS code)
# Chronic combined systolic and diastolic HF (heart failure) (CMS code)
# Elevated serum creatinine
# Recurrent appendicitis
# History of Crohn's disease
# Acute recurrent pancreatitis
# Hepatic encephalopathy (CMS code)
# Adenomyosis
# Alcohol use disorder
# Acute biliary pancreatitis, unspecified complication status
# Fall, initial encounter
# Bilateral flank pain
# Swelling of left lower extremity
# Acute on chronic HFrEF (heart failure with reduced ejection fraction) (CMS code)
# Shortness of breath
# Heart failure, unspecified HF chronicity, unspecified heart failure type (CMS code)
# Asthma with acute exacerbation, unspecified asthma severity, unspecified whether persistent
# Acute exacerbation of chronic obstructive pulmonary disease (COPD) (CMS code)
# Tachypnea
# Pleural effusion
# DOE (dyspnea on exertion)
# Dyspnea, unspecified type
# Pleuritic chest pain
# Chest pain
# Acute saddle pulmonary embolism without acute cor pulmonale (CMS code)
# Community acquired pneumonia, unspecified laterality
# Community acquired pneumonia of left lung, unspecified part of lung
# SOB (shortness of breath)
# Hemoptysis
# Acute HFrEF (heart failure with reduced ejection fraction) (CMS code)
# Pneumonia of both lungs due to infectious organism, unspecified part of lung
# Community acquired pneumonia of right lung, unspecified part of lung
# Acute nonintractable headache, unspecified headache type
# History of heart failure
# Prostate cancer (CMS code)
# Interstitial lung disease (CMS code)
# Acute hypoxemic respiratory failure (CMS code)
# Focal seizures (CMS code)
# Dilated cardiomyopathy (CMS code)
# PAD (peripheral artery disease) (CMS code)
# Surgical wound dehiscence, initial encounter
# Hypervolemia, unspecified hypervolemia type
# Acute systolic heart failure (CMS code)
# Pneumonia of right lower lobe due to infectious organism
# Community acquired pneumonia of right lower lobe of lung
# Acute respiratory failure with hypoxia (CMS code)
# Atrial fibrillation and flutter (CMS code)
# Dyspnea
# Acute decompensated heart failure (CMS code)
# Cough, unspecified type
# Aspiration pneumonia of both lower lobes due to vomit (CMS code)
# Acute aspiration pneumonia (CMS code)
# Mass of left lung
# Pulmonary embolism on left (CMS code)
# PAF (paroxysmal atrial fibrillation) (CMS code)
# Lung transplant recipient (CMS code)
# NSTEMI (non-ST elevated myocardial infarction) (CMS code)
# Pneumonia of right upper lobe due to infectious organism
# Atrial fibrillation with rapid ventricular response (CMS code)
# Acute on chronic congestive heart failure, unspecified heart failure type (CMS code)
# HIV infection, unspecified symptom status (CMS code)
# ILD (interstitial lung disease) (CMS code)
# Congestive heart failure with left ventricular dysfunction (CMS code)
# History of type 2 diabetes mellitus
# Community acquired pneumonia of right upper lobe of lung
# Airway obstruction
# Adenocarcinoma of gallbladder (CMS code)
# Stage 5 chronic kidney disease not on chronic dialysis (CMS code)
# Diastolic heart failure due to valvular disease, unspecified heart failure chronicity (CMS code)
# Pneumothorax, unspecified type
# COPD exacerbation (CMS code)
# Severe anemia
# Acute on chronic heart failure with preserved ejection fraction (HFpEF) (CMS code)
# Acute on chronic respiratory failure with hypoxia and hypercapnia (CMS code)
# Hyperglycemia
# Hypertension, unspecified type
# Pneumonia of left lower lobe due to infectious organism
# Abdominal wall abscess
# Lightheadedness
# Abscess of right lung with pneumonia, unspecified part of lung (CMS code)
# Status post lung transplantation (CMS code)
# Edema of both legs
# Alcoholic cirrhosis of liver with ascites (CMS code)
# Hypertensive emergency
# Hepatic cirrhosis, unspecified hepatic cirrhosis type, unspecified whether ascites present (CMS code)
# Pulmonary hypertension (CMS code)
# Gastrostomy tube dependent (CMS code)
# Right-sided heart failure, unspecified HF chronicity (CMS code)
# Iron deficiency anemia, unspecified iron deficiency anemia type
# Infective endocarditis of tricuspid valve
# Aspiration pneumonia of both lungs, unspecified aspiration pneumonia type, unspecified part of lung (CMS code)
# DVT of deep femoral vein, bilateral (CMS code)
# Cytomegalovirus infection, unspecified cytomegaloviral infection type (CMS code)
# Pancreatic mass
# Altered level of consciousness
# Arteriosclerosis of arteries of extremities (CMS code)
# Chronic obstructive pulmonary disease, unspecified COPD type (CMS code)
# Stable angina (CMS code)
# Persistent atrial fibrillation (CMS code)
# Stage IV adenocarcinoma of lung, unspecified laterality (CMS code)
# Aspiration pneumonia of right lower lobe, unspecified aspiration pneumonia type (CMS code)
# Cough
# Congestive heart failure (CHF) (CMS code)
# Flash pulmonary edema (CMS code)
# Acute cystitis without hematuria
# Multiple myeloma without remission (CMS code)
# Pneumonia of right middle lobe due to infectious organism
# Pneumonia of both upper lobes due to infectious organism
# Pneumothorax on right
# Metabolic acidosis, increased anion gap
# Nasal congestion
# Exacerbation of asthma, unspecified asthma severity, unspecified whether persistent
# Pleomorphic cell sarcoma (CMS code)
# Multilobar lung infiltrate
# Syncope and collapse
# Acute dyspnea
# Stimulant use disorder
# Pulmonary nodules
# Chronic ear pain, bilateral
# Pleural effusion, bilateral
# Acute pericarditis, unspecified type
# Elevated troponin
# Typical atrial flutter (CMS code)
# Right upper extremity numbness
# Acute pancreatitis, unspecified complication status, unspecified pancreatitis type
# Grade III hemorrhoids
# RUQ pain
# Failure to thrive in adult
# Microscopic hematuria
# Neutropenia, unspecified type (CMS code)
# Acute right-sided thoracic back pain
# Bronchitis
# Diffuse pain
# Airway compromise
# Exertional chest pain
# Symptomatic hypotension
# H/O heart transplant (CMS code)
# Positive cardiac stress test
# Heart transplant recipient (CMS code)
# At increased risk for stress
# Paroxysmal atrial fibrillation (CMS code)
# Pressure in head
# Systolic heart failure, unspecified HF chronicity (CMS code)
# Spontaneous pneumothorax
# Minimal change disease
# Near syncope
# Left chest pressure
# Acute chest pain
# Chest discomfort
# Sickle cell anemia with pain (CMS code)
# ESRD on hemodialysis (CMS code)
# Septic arthritis, due to unspecified organism, septic arthritis of unspecified location (CMS code)
# S/P TAVR (transcatheter aortic valve replacement)
# Atypical chest pain
# Chest tightness
# Other pulmonary embolism without acute cor pulmonale, unspecified chronicity (CMS code)
# Atrial fibrillation, unspecified type (CMS code)
# Bilateral hip pain
# Sternal wound infection
# Acute pain
# Neck pain
# Back abscess
# Myalgia
# Demand ischemia (CMS code)
# SO-JIA (systemic onset juvenile idiopathic arthritis) (CMS code)
# Back pain, subacute
# Palpitations
# Hypotension, unspecified hypotension type
# Hypogonadism male
# Cystic fibrosis (CMS code)
# Clot
# Troponin level elevated
# Numbness
# Atrial fibrillation with RVR (CMS code)
# Lower extremity edema
# Intermittent left-sided chest pain
# Confusion
# Pericardial effusion
# Left-sided chest pain
# Ischemic cardiomyopathy
# Syncope, unspecified syncope type
# Ground-level fall
# Closed fracture dislocation of cervical spine, initial encounter (CMS code)
# Hip fracture, left, closed, initial encounter (CMS code)
# Acute exacerbation of chronic low back pain
# Head injury, acute, initial encounter
# Vision changes
# Closed right trimalleolar fracture, initial encounter
# Nondisplaced fracture of anterior column (iliopubic) of left acetabulum, initial encounter for closed fracture (CMS code)
# Closed fracture of multiple pubic rami, left, initial encounter (CMS code)
# Prostate cancer metastatic to bone (CMS code)
# Acute midline low back pain without sciatica
# History of humerus fracture
# Closed fracture of shaft of right femur, initial encounter (CMS code)
# Traumatic closed fracture of femoral condyle with minimal displacement, right, initial encounter (CMS code)
# Closed fracture of femur, intertrochanteric, left, initial encounter (CMS code)
# Dizziness
# Closed head injury, initial encounter
# Nondisplaced fracture of medial cuneiform of right foot, initial encounter for closed fracture
# SAH (subarachnoid hemorrhage) (CMS code)
# Hip fracture, right, closed, initial encounter (CMS code)
# Fall from ground level
# Right hip pain
# Hip pain, acute, left
# Hypernatremia
# Effusion of both knee joints
# Hip fracture, left, sequela
# Subdural hematoma (CMS code)
# Closed fracture of proximal end of humerus, initial encounter
# Recurrent falls
# Closed displaced spiral fracture of shaft of humerus, initial encounter
# Closed fracture of sacrum, unspecified fracture morphology, initial encounter (CMS code)
# Chest wall pain
# SDH (subdural hematoma) (CMS code)
# Bimalleolar fracture of left ankle, closed, initial encounter
# Hip pain
# Lumbar burst fracture, closed, initial encounter (CMS code)
# Intracranial contusion (CMS code)
# Housing instability
# Tibial plateau fracture, right, closed, initial encounter
# Knee pain, unspecified chronicity, unspecified laterality
# Hip pain, acute, right
# Frequent falls
# Parkinson's disease (CMS code)
# Moderate right ankle sprain, initial encounter
# Wrist fracture, closed, left, initial encounter
# Unresponsiveness
# Rib pain on left side
# Closed fracture of right hip, initial encounter (CMS code)
# Multiple fractures of ribs, unspecified side, initial encounter for closed fracture
# Acute alcohol intoxication, uncomplicated (CMS code)
# Acute pain of right knee
# Laceration of head, complicated, initial encounter
# Abrasion of right knee, initial encounter
# Bruised ribs, left, sequela
# Right arm fracture, closed, initial encounter
# Closed fracture of transverse process of lumbar vertebra, initial encounter (CMS code)
# Fall (on)(from) sidewalk curb, initial encounter
# Tibia/fibula fracture, left, closed, initial encounter
# Breast cancer metastasized to multiple sites, unspecified laterality (CMS code)
# Dens fracture, closed, initial encounter (CMS code)
# Nondisplaced fracture of greater trochanter of right femur, initial encounter for closed fracture (CMS code)
# Hip dislocation, right, initial encounter (CMS code)
# Acute hip pain, right
# Cervical stenosis of spine
# Benzodiazepine abuse (CMS code)
# Alcoholic intoxication without complication (CMS code)
# Fatigue, unspecified type
# Weakness of right lower extremity
# Hypokalemia
# Gait instability
# Seizure (CMS code)
# Malaise
# Weakness of left leg
# Esophagitis
# Parkinson disease, symptomatic (CMS code)
# Pulmonary edema cardiac cause (CMS code)
# Hypoglycemia
# Pseudoaneurysm of pancreatic artery (CMS code)
# Abscess
# Weakness
# Low back pain, unspecified back pain laterality, unspecified chronicity, unspecified whether sciatica present
# Pneumonia of left lung due to infectious organism, unspecified part of lung
# Bipolar I disorder, most recent episode (or current) manic (CMS code)
# JDMS (juvenile dermatomyositis) (CMS code)
# Metastatic breast cancer
# Acute ischemic stroke (CMS code)
# CNS lymphoma (CMS code)
# Pelvic mass
# Duodenitis
# CAP (community acquired pneumonia) due to Mycoplasma pneumoniae
# Symptomatic anemia
# Essential hypertension
# Epidural hematoma (CMS code)
# Pancreatic adenocarcinoma (CMS code)
# Left-sided weakness
# Rectal cancer (CMS code)
# Hypercalcemia
# Acute cystitis with hematuria
# Hemodialysis patient (CMS code)
# COVID-19 virus infection
# Atrial flutter, unspecified type (CMS code)
# Neutrophilic leukocytosis
# Elevated glucose level
# Sleepiness
# Psychiatric disorder
# Disequilibrium
# Mitral stenosis, subvalvar
# Metastasis from malignant neoplasm of kidney (CMS code)
# Acute psychosis (CMS code)
# Acute cerebrovascular accident (CVA) (CMS code)
# Suicide ideation
# Word finding difficulty
# At risk for danger to others
# Shaking
# Parkinson disease (CMS code)
# Glioblastoma (CMS code)
# Open neck wound, initial encounter
# Head trauma, initial encounter
# Septic shock (CMS code)
# FTT (failure to thrive) in adult
# Fungal rash of trunk
# Dilated gallbladder
# Metastatic malignant neoplasm, unspecified site (CMS code)
# Psychosis, paranoid (CMS code)
# Amphetamine intoxication, uncomplicated (CMS code)
# Confusion and disorientation
# Fall in elderly patient
# Encephalitis due to human herpes simplex virus (HSV)
# Opiate overdose, accidental or unintentional, initial encounter (CMS code)
# Aphasia
# ETOH abuse
# Methamphetamine intoxication (CMS code)
# Gastrointestinal hemorrhage, unspecified gastrointestinal hemorrhage type
# Hydrocephalus, unspecified type (CMS code)
# Facial cellulitis
# Dysuria
# Severe sepsis (CMS code)
# Fever
# Polyarticular gout
# SIRS (systemic inflammatory response syndrome) (CMS code)
# Status post liver transplant (CMS code)
# Soft tissue infection
# Diabetes mellitus secondary to pancreatic insufficiency (CMS code)
# Abdominal tenderness, rebound tenderness presence not specified, unspecified location
# Perihepatic abscess (CMS code)
# Chemotherapy-induced neutropenia (CMS code)
# Neutropenic fever (CMS code)
# Acute viral syndrome
# Febrile neutropenia (CMS code)
# Bile leak
# Cholangitis (CMS code)
# History of bacteremia
# SBP (spontaneous bacterial peritonitis) (CMS code)
# Metastatic lung carcinoma, right (CMS code)
# Kidney stone on left side
# Nasopharyngeal cancer (CMS code)
# Fever, unknown origin
# Preseptal cellulitis of left eye
# Crohn's colitis, with fistula (CMS code)
# Acute pharyngitis, unspecified etiology
# Fever in other diseases
# Fever and chills
# Diabetic ketoacidosis without coma associated with diabetes mellitus due to underlying condition (CMS code)
# Right flank pain
# Behavior disturbance
# Catatonia
# Psychiatric diagnosis
# Mental health disorder
# At risk for intentional self-harm
# Bizarre behavior
# Anxiety
# Housing instability, currently housed
# Psychosis, unspecified psychosis type (CMS code)
# Visual hallucinations
# Adverse effect of nitrous oxide
# Auditory hallucination
# Suicidal ideation
# Schizoaffective disorder, bipolar type (CMS code)
# Bipolar 1 disorder (CMS code)
# Depression, major, recurrent, severe with psychosis (CMS code)
# Suicide attempt (CMS code)
# Cellulitis of lower extremity, unspecified laterality
# Schizophrenia, unspecified type (CMS code)
# Psychoactive substance-induced psychosis (CMS code)
# Auditory hallucinations
# Agitation
# Schizoaffective disorder, unspecified type (CMS code)
# Psychosis, atypical (CMS code)
# Paranoia (CMS code)
# Mania (CMS code)
# Opioid use disorder
# Disorganized schizophrenia (CMS code)
# Hallucinations
# Behavior concern
# Heart transplanted (CMS code)
# Substance use disorder
# History of alcohol use disorder
# Wound dehiscence
# Bipolar affective disorder, remission status unspecified (CMS code)
# Delusions (CMS code)
# History of schizophrenia
# Left leg cellulitis
# Cognitive and behavioral changes
# Methamphetamine use disorder, moderate (CMS code)
# Schizo affective schizophrenia (CMS code)
# Depression with suicidal ideation
# Leg swelling
# Depression, unspecified depression type
# Abscess, perineum
# Agitation requiring sedation protocol
# Needs assistance with community resources
# Immunocompromised (CMS code)
# Psychosis, affective (CMS code)
# Tylenol overdose, accidental or unintentional, initial encounter
# Small cell lung cancer (CMS code)
# Vertigo
# Postural dizziness with presyncope
# Acute migraine
# Hypertension complications
# Cardiogenic shock (CMS code)
# Episodic lightheadedness
# Migraine syndrome
# Myocardial injury
# Unstable gait
# Light headedness
# Dizzy
# Ear lobe laceration, right, initial encounter
# AICD discharge
# Transaminitis
# Ataxia
# Symptomatic bradycardia
# Meningioma (CMS code)
# Vestibular migraine
# Cerebellar stroke (CMS code)
# TIA (transient ischemic attack)
# History of diverticular abscess
# BPPV (benign paroxysmal positional vertigo), bilateral
# Gait abnormality
# Malignant pleural effusion (CMS code)
# Anemia requiring transfusions
# Elevated blood sugar
# Balance problem
# Renal cell carcinoma, unspecified laterality (CMS code)
# Ear infection
# VP (ventriculoperitoneal) shunt status
# Metastasis to brain (CMS code)
# Dehydration
# Cerebrovascular accident (CVA), unspecified mechanism (CMS code)
# Nonintractable headache, unspecified chronicity pattern, unspecified headache type
# Subarachnoid hemorrhage (CMS code)
# Vision loss of left eye
# Cervical radiculopathy
# Acute non intractable tension-type headache
# Generalized headache
# Numbness and tingling of left arm and leg
# Clear cell carcinoma (CMS code)
# Migraine without aura and responsive to treatment
# Closed compression fracture of body of L1 vertebra (CMS code)
# Lumbar herniated disc
# Concussion syndrome
# Acute intractable headache, unspecified headache type
# Leukocytosis, unspecified type
# Breast cancer metastasized to liver, unspecified laterality (CMS code)
# Facial spasm
# Headache
# Physical assault
# Cerebral venous sinus thrombosis
# History of idiopathic intracranial hypertension
# Medication refill
# Upper back pain
# Spasm of muscle of lower back
# Lumbar back pain
# Compression fracture of T7 vertebra, sequela
# Hernia
# Spinal cord injury at T1-T6 level (CMS code)
# Back pain associated with peripheral numbness
# T12 compression fracture, initial encounter (CMS code)
# Sickle cell pain crisis (CMS code)
# Left leg weakness
# Ureteral cancer, right (CMS code)
# Chronic thoracic back pain, unspecified back pain laterality
# Pelvic pain
# Mid back pain
# Spinal stenosis, unspecified spinal region
# Chronic bilateral low back pain, unspecified whether sciatica present
# Sacral ulcer, limited to breakdown of skin (CMS code)
# Flu
# Discitis, unspecified spinal region
# Back pain with radiculopathy
# Spinal stenosis of lumbar region with radiculopathy
# T12 compression fracture, sequela
# Sickle cell crisis (CMS code)
# Back pain with sciatica
# Closed compression fracture of L3 lumbar vertebra, initial encounter (CMS code)
# Primary lung cancer, unspecified laterality (CMS code)
# Acute left-sided low back pain without sciatica
# Lumbar disc herniation
# Feeling unwell
# Lumbar compression fracture, closed, initial encounter (CMS code)
# Arm numbness
# Left hip pain
# Closed compression fracture of L2 lumbar vertebra, initial encounter (CMS code)
# Lung cancer associated cerebellar ataxia (CMS code)
# Metabolic acidosis
# Lumbar strain, initial encounter
# Acute kidney injury superimposed on chronic kidney disease (CMS code)
# Pleural effusion, left
# Hematoma
# Epidural abscess
# Ureteral calculus
# Acute bilateral low back pain with bilateral sciatica
# Adrenal crisis (CMS code)
# H. pylori infection
# Non-intractable vomiting with nausea, unspecified vomiting type
# Dental infection
# Left lower quadrant abdominal pain
# Intractable nausea and vomiting
# Nausea and vomiting in pregnancy
# Mucormycosis (CMS code)
# Duodenal ulcer
# Malignant neoplasm of pancreas, unspecified location of malignancy (CMS code)
# Intractable vomiting with nausea, unspecified vomiting type
# Influenza A
# Bone abscess (CMS code)
# Mastoiditis, unspecified laterality
# DKA, type 1, not at goal (CMS code)
# Pneumothorax on left
# Lactate blood increase
# DKA, type 2, not at goal (CMS code)
# Papilledema
# Primary lung adenocarcinoma, unspecified laterality (CMS code)
# LUQ pain
# Postoperative abscess
# Personal history of DVT (deep vein thrombosis)
# CSF leak
# Diaphragm injury, initial encounter
# Esophageal dysphagia
# Nasopharyngeal carcinoma (CMS code)
# Crohn's colitis, with abscess (CMS code)
# Port or reservoir infection, initial encounter
# Carcinoma of breast metastatic to multiple sites, unspecified laterality (CMS code)
# Groin pain, left
# Brain mass
# Blood in the stool
# Parotiditis
# Rash
# Discitis of lumbar region
# Other hydronephrosis
# Acute right flank pain
# Acute renal failure, unspecified acute renal failure type (CMS code)
# Complication of AV dialysis fistula, initial encounter
# PMR (polymyalgia rheumatica) (CMS code)
# Encounter for lumbar puncture
# Vision disturbance
# Pericardial tamponade
# Encounter for Foley catheter replacement
# Myelofibrosis (CMS code)
# Acute lymphoblastic leukemia (ALL) in relapse (CMS code)
# Elevated bilirubin
# Shunt malfunction, initial encounter
# Left facial swelling
# Weight loss
# Pneumonia due to COVID-19 virus
# Tachycardia
# UTI due to extended-spectrum beta lactamase (ESBL) producing Escherichia coli
# CHF (congestive heart failure) (CMS code)
# Soft tissue swelling
# Diverticulitis of large intestine with complication
# Other acute osteomyelitis of right foot (CMS code)
# Pain crisis
# Bilateral cellulitis of lower leg
# Pain in both lower extremities
# Type 2 diabetes mellitus with diabetic toe ulcer (CMS code)
# Closed trimalleolar fracture of left ankle, initial encounter
# Right leg pain
# Cellulitis of right lower extremity
# Acute left ankle pain
# DVT, lower extremity, proximal, acute, right (CMS code)
# Cold exposure, initial encounter
# Left leg pain
# Gastrocnemius muscle tear, right, initial encounter
# Cellulitis of finger of left hand
# Leg pain, bilateral
# Acute right-sided low back pain with right-sided sciatica
# Peripheral artery disease (CMS code)
# Fracture of left leg, closed, initial encounter
# Cellulitis of left lower extremity
# Leg pain, anterior, left
# Paresthesias
# Nondisplaced fracture of distal end of fibula
# Right calf pain
# Cellulitis of right leg
# Tibia/fibula fracture, right, closed, initial encounter
# Foot pain, bilateral
# Somnolence
# Pain of right lower extremity
# Acute gout of right knee, unspecified cause
# Pleural effusion on right
# Radiculopathy, unspecified spinal region
# Seizure-like activity (CMS code)
# Syncope
# Pericardial effusion with cardiac tamponade
# Vasovagal near-syncope
# Metastatic melanoma (CMS code)
# Acidosis
# Coronary artery disease involving native coronary artery of native heart without angina pectoris
# Bilateral chronic knee pain
# Postural hypotension
# Prolonged Q-T interval on ECG
# Pre-syncope
# Vasculitis (CMS code)
# Anemia of chronic disease
# Pseudomonas infection
# Malignant neoplasm of urinary bladder, unspecified site (CMS code)
# Renal failure, unspecified chronicity
# Lupus nephritis (CMS code)
# Positive blood culture
# Acute liver disease
# Thrombocytosis
# Bacteremia
# Acute GI bleeding
# Osteosarcoma (CMS code)
# Germ cell tumor of right testicle (CMS code)
# Acute hyperkalemia
# INR (international normal ratio) abnormal
# Seizures (CMS code)
# Bupropion overdose, accidental or unintentional, initial encounter
# Autonomic dysfunction
# Epilepsy, generalized, convulsive (CMS code)
# Spell of behavior change
# Positive glutamic acid decarboxylase antibody
# Convulsions, unspecified convulsion type (CMS code)
# Episode of shaking
# Aspiration pneumonia of left lower lobe due to vomit (CMS code)
# Encephalitis
# Psychogenic nonepileptic seizure
# Focal epilepsy with impairment of consciousness (CMS code)
# Benzodiazepine withdrawal with delirium (CMS code)
# Seizure disorder (CMS code)
# Pseudohyponatremia
# Salicylate overdose, accidental or unintentional, sequela
# Uremia
# Hypercalcemia of malignancy
# Abnormal laboratory test
# Lung cancer metastatic to brain (CMS code)
# Hyperbilirubinemia
# Exacerbation of systemic lupus (CMS code)
# Pancytopenia (CMS code)
# Acute on chronic anemia
# Community acquired pneumonia of left lower lobe of lung
# Acute upper respiratory infection
# Nonproductive cough
# Recurrent bronchiectasis (CMS code)
# Community acquired bacterial pneumonia
# Peritonsillar abscess
# Fever in adult
# Sore throat
# Wheezing
# Flu-like symptoms
# Lung infection
# Flank pain
# Acute right-sided low back pain, unspecified whether sciatica present
# Cholecystitis
# Anal fissure
# Hydronephrosis of right kidney
# Kidney stones
# Renal stone
# Urothelial cancer (CMS code)
# Right kidney stone
# Acute flank pain
# Hematuria, unspecified type
# Central line complication, initial encounter
# Complaints of weakness of lower extremity
# DVT, lower extremity, distal, acute, right (CMS code)
# Altered olfactory perception
# Anasarca
# Hemorrhage from tracheostomy stoma (CMS code)
# Oral bleeding
# Major depression, chronic
# Allodynia
# Vaso-occlusive pain due to sickle cell disease (CMS code)
# Foley catheter problem, initial encounter (CMS code)
# Nasal septal abscess
# Gastric tube granulation tissue (CMS code)
# Bilateral lower extremity edema
# Hypothermia, initial encounter
# Acute left-sided CHF (congestive heart failure) (CMS code)
# Congestive heart failure, unspecified HF chronicity, unspecified heart failure type (CMS code)
# Acute kidney injury (CMS code)
# Lymphedema
# Leg injury, left, initial encounter
# Bilateral leg weakness
# Edema, unspecified type
# Tibia/fibula fracture, left, sequela
# Hepatitis
# Bilateral leg edema
# Acute UTI
# Empyema (CMS code)
# Intractable diarrhea
# Diarrhea of infectious origin
# Chronic heart failure with reduced ejection fraction and diastolic dysfunction (CMS code)
# Diarrhea of presumed infectious origin
# Acute prostatitis
# HFrEF (heart failure with reduced ejection fraction) (CMS code)
# S/P renal autotransplant
# Hematuria
# Hematuria, gross
# Acute encephalopathy
# Vasoocclusive sickle cell crisis (CMS code)
# Primary hypertension
# Whole body pain
# Acute osteomyelitis of coccyx (CMS code)
# Infected ulcer of skin, unspecified ulcer stage (CMS code)
# Soft tissue infection of foot
# Chronic cutaneous venous stasis ulcer (CMS code)
# Meningocele (CMS code)
# Wound cellulitis
# Visit for wound check
# Foot infection
# Acute pain of left knee
# Toe gangrene (CMS code)
# Cellulitis of left upper extremity
# Closed right hip fracture, initial encounter (CMS code)
# Hip dislocation, right, subsequent encounter
# Closed fracture of neck of left femur, initial encounter (CMS code)
# Closed dislocation of right hip, initial encounter (CMS code)
# Leg pain, diffuse, left
# Closed anterior dislocation of left hip, initial encounter (CMS code)
# Closed displaced dome fracture of right acetabulum, initial encounter (CMS code)
# Pain in left lower leg
# Back pain, lumbosacral
# Left displaced femoral neck fracture (CMS code)
# Pressure injury of deep tissue of sacral region
# Morel Lavallee lesion
# Pain from bone metastases (CMS code)
# Acute low back pain with sciatica, sciatica laterality unspecified, unspecified back pain laterality
# Post-operative nausea and vomiting
# Infrarenal abdominal aortic aneurysm (AAA) without rupture (CMS code)
# Endometrial cancer (CMS code)
# Reducible umbilical hernia
# Cold sweat
# Penile discharge
# Pseudoaneurysm (CMS code)
# Pacemaker pocket hematoma, sequela
# Postoperative fever
# Fluid collection at surgical site, initial encounter
# Squamous cell carcinoma of face
# S/P hemorrhoidectomy
# Postprocedural intraabdominal abscess
# Gangrene of toe (CMS code)
# Diastolic heart failure, unspecified HF chronicity (CMS code)
# Malfunction of nephrostomy tube (CMS code)
# Nasal pain
# Surgical wound infection
# Status post kidney transplant
# Dehydration symptoms
# CP (cerebral palsy), mixed (CMS code)
# LVAD (left ventricular assist device) present (CMS code)
# Lumbar radicular pain
# Right sided weakness
# Hypotension
# Feeding difficulty in adult
# Bradycardia
# Bell's palsy
# MS (multiple sclerosis) (CMS code)
# Numbness and tingling of right arm
# Colon cancer metastasized to liver (CMS code)
# Facial numbness
# Right facial numbness
# Internal carotid artery stenosis, left
# Leg weakness, bilateral
# Dysarthria
# Limb ischemia
# Paresthesia
# Numbness and tingling of both lower extremities
# Numbness and tingling of left lower extremity
# Ischemic stroke (CMS code)
# SVT (supraventricular tachycardia) (CMS code)
# ESRD (end-stage renal disease) due to SLE (CMS code)
# Heartburn
# Heart palpitations
# Atypical atrial flutter (CMS code)
# Cardiac arrhythmia, unspecified cardiac arrhythmia type
# Renal insufficiency
# Neuroendocrine tumor (CMS code)
# Body aches
# Myopericarditis
# Perforated appendicitis
# Fever of unknown origin
# Urinary incontinence, unspecified type
# Chronic kidney disease, stage 3b (CMS code)
# Elevated liver function tests
# HTN (hypertension), benign
# Episodic tension-type headache, not intractable
# Hypertensive urgency
# Witnessed syncope
# Encephalopathy chronic
# Tooth abscess
# Elevated blood pressure reading
# High blood pressure determined by examination
# Initial high blood pressure determined by examination
# Asymptomatic hypertension
# Labile essential hypertension
# Suprapubic catheter (CMS code)
# Acute urinary retention
# Peritoneal carcinomatosis (CMS code)
# Difficulty urinating
# Dark stools
# Back pain, unspecified back location, unspecified back pain laterality, unspecified chronicity
# Frank blood in stool
# Lower GI bleed
# Hematochezia
# Rectal bleeding
# Dislodged gastrostomy tube
# Clogged feeding tube
# Malfunction of jejunostomy tube (CMS code)
# Feeding by G-tube (CMS code)
# Encounter for nasojejunal (NJ) tube placement
# Gastrojejunostomy tube dislodgement
# Feeding difficulties
# Feeding tube blocked, initial encounter
# Gastrostomy tube dysfunction (CMS code)
# Feeding tube dysfunction, initial encounter
# Superior mesenteric artery syndrome (CMS code)
# Blister (nonthermal), left foot, initial encounter
# Cellulitis of foot
# Foot laceration, right, initial encounter
# Contusion of left foot or heel
# Displaced fracture of medial malleolus of right tibia, initial encounter for closed fracture
# Chronic wound
# Chronic pain of both feet
# Discoloration of skin of toe
# Cellulitis of foot, left
# Oligo FI metCSPC (oligometastatic (<=5 mets) castrate-sensitive prostate cancer by functional imaging)  (CMS code)
# Cardiac arrest (CMS code)
# Ulcerative colitis without complications, unspecified location (CMS code)
# Diabetic ulcer of right midfoot associated with type 2 diabetes mellitus, with bone involvement without evidence of necrosis (CMS code)
# Infection due to spinal fixation device, initial encounter (CMS code)
# Ankle wound, left, initial encounter
# Pyomyositis
# H/O ankylosing spondylitis
# Leg ulcer, right, with unspecified severity (CMS code)
# Intertrigo
# Wound of left lower extremity, sequela
# Finger infection
# Infection of prosthetic joint, initial encounter (CMS code)
# Cryptogenic stroke (CMS code)
# Dialysis patient (CMS code)
# Facial droop
# Aneurysm (CMS code)
# Progressive supranuclear palsy (CMS code)
# Lethargy
# Unable to perform basic transfer without assistance
# Esophageal adenocarcinoma (CMS code)
# Metastatic malignant neoplasm to breast (CMS code)
# Ventricular tachycardia (CMS code)
# Elevated troponin level not due myocardial infarction
# Gallbladder carcinoma (CMS code)
# Metastatic adenocarcinoma to bladder (CMS code)
# Osteomyelitis of cervical vertebra (CMS code)
# History of hypertension
# Vertebral artery dissection (CMS code)
# Mucositis
# Fracture of anterior arch of C1, sequela
# Alcohol withdrawal delirium (CMS code)
# Draining sinus due to chronic osteomyelitis of right lower leg (CMS code)
# Hemophilia A (CMS code)
# Closed comminuted fracture of patella, right, initial encounter
# Hemarthrosis of right knee
# Bacterial infection of knee joint (CMS code)
# Right knee pain, unspecified chronicity
# Orbital cellulitis on left
# Dry eye
# Visual disturbance
# Periorbital cellulitis of left eye
# Ophthalmic herpes zoster infection
# Preseptal cellulitis
# Acute arterial ischemic stroke, multifocal, posterior circulation, left (CMS code)
# Maxillary sinus mass
# Vitreous hemorrhage of left eye (CMS code)
# Vitreous hemorrhage, unspecified laterality (CMS code)
# Posterior vitreous detachment of left eye
# ANCA-associated vasculitis (CMS code)
# Optic neuritis
# B-cell acute lymphoblastic leukemia (ALL) (CMS code)
# Slurred speech
# Dysphagia, unspecified type
# Abscess and cellulitis of gluteal region
# Perianal abscess
# Anal abscess
# Hyperosmolar hyperglycemic state (HHS) (CMS code)
# Anal cellulitis
# Cellulitis and abscess of leg
# Pain, dental
# Corneal abrasion of both eyes, initial encounter
# Cellulitis of lower back
# Hepatic abscess
# Abscess of gluteal region
# Soft tissue abscess
# Blisters of multiple sites
# Alcohol ingestion
# Pain due to ureteral stent, subsequent encounter
# Urinary tract infection associated with indwelling urethral catheter, initial encounter (CMS code)
# Acute renal insufficiency
# Diabetic ketoacidosis without coma associated with type 1 diabetes mellitus (CMS code)
# BRBPR (bright red blood per rectum)
# Bright red rectal bleeding
# Problem with dialysis access, initial encounter (CMS code)
# Encounter for care related to Port-a-Cath
# AV fistula occlusion, initial encounter (CMS code)
# Complication associated with dialysis catheter
# Complication associated with peripherally inserted central catheter (PICC), initial encounter
# Clotted renal dialysis AV graft, sequela
# Hemophilia (CMS code)
# Problem with vascular access
# Acute bilateral low back pain, unspecified whether sciatica present
# Presence of intrathecal baclofen pump
# History of lung cancer
# Neuromyelitis optica (CMS code)
# Left upper arm pain
# Cellulitis of left leg
# Cellulitis of right hip
# Cellulitis of neck
# Fever, unspecified
# Lower extremity venous stasis
# Open leg wound, left, initial encounter
# Cat bite of right hand with infection, initial encounter
# Left foot pain
# Uterine leiomyoma, unspecified location
# Adjustment disorder with depressed mood
# Ingestion of substance, intentional self-harm, initial encounter (CMS code)
# Accidental fentanyl overdose, initial encounter (CMS code)
# Drug overdose of undetermined intent, initial encounter
# Glasgow coma scale total score 3-8, at hospital admission (CMS code)
# Opioid overdose, accidental or unintentional, initial encounter (CMS code)
# Disseminated zoster
# Anaphylaxis, initial encounter
# Eczema herpeticum
# Erythematous rash
# Infection due to Mycobacterium genavense
# Rectal perforation (CMS code)
# Chronic idiopathic constipation
# Right arm pain
# Cervical disc herniation
# Non-traumatic rhabdomyolysis
# Cellulitis of other specified site
# Elbow arthritis
# Pain of right side of body
# Stiff person syndrome
# Gout, unspecified cause, unspecified chronicity, unspecified site
# Epistaxis
# Epistaxis, recurrent
# Postsurgical epistaxis
# Abnormal uterine bleeding (AUB)
# Vaginal bleeding
# Rhinorrhea
# Infection of nose
# Swelling of right index finger
# Arm swelling
# Open wounds of multiple sites of hand, initial encounter
# Cellulitis and abscess of hand
# Flexor tenosynovitis of finger
# Cellulitis of hand
# Alcohol use with withdrawal (CMS code)
# Opiate withdrawal (CMS code)
# Gangrenous cholecystitis
# Other osteomyelitis, multiple sites (CMS code)
# Pseudogout
# Shock (CMS code)
# Esophageal stricture
# Tonsillitis
# Chronic post-traumatic headache, not intractable
# Aspiration into lower respiratory tract, initial encounter
# Abnormal finding of diagnostic imaging
# Dissection of aorta, unspecified portion of aorta (CMS code)
# Closed fracture of left hip, initial encounter (CMS code)
# Abdominal distention
# UTI (urinary tract infection), bacterial
# Wound, open
# Acute pyelonephritis
# Hematemesis with nausea
# Small bowel obstruction (CMS code)
# Enterocolitis
# Swelling of joint of upper arm, right
# PICC line infection, initial encounter
# Cephalic vein thrombosis
# Corneal ulcer of left eye
# DVT of axillary vein, acute right (CMS code)
# Thyroid cancer (CMS code)
# Neck swelling
# Mild tongue swelling
# Pustular rash
# Acute neck pain
# Acute left-sided thoracic back pain
# Left elbow pain
# Shoulder pain, unspecified chronicity, unspecified laterality
# Acute pain of right shoulder
# Closed fracture dislocation of left shoulder joint, initial encounter
# Breast cancer metastasized to bone, unspecified laterality (CMS code)
# Dental abscess
# Multiple myeloma in relapse (CMS code)
# Cystic lesion of mandible determined by X-ray
# Right facial swelling
# Facial swelling
# Pheochromocytoma of left adrenal gland
# Abdominal pain, chronic, epigastric
# NF2 (neurofibromatosis 2) (CMS code)
# S/P VP shunt
# Myelitis (CMS code)
# Bloody stool
# Fracture of fibula alone
# Ankle fracture, bimalleolar, closed, right, initial encounter
# Injury while roller skating
# Other osteonecrosis, right ankle (CMS code)
# Pain and swelling of right ankle
# Acute loss of vision, bilateral
# Cellulitis of right orbital region
# Adenovirus infection
# Alcohol withdrawal syndrome with complication (CMS code)
# Gastroesophageal cancer (CMS code)
# Pneumomediastinum (CMS code)
# Squamous cell carcinoma of oral mucosa (CMS code)
# Achalasia
# Irregular heart beat
# Respiratory failure, unspecified chronicity, unspecified whether with hypoxia or hypercapnia (CMS code)
# Ventricular fibrillation (CMS code)
# Pneumothorax after biopsy
# Closed compression fracture of L4 lumbar vertebra, initial encounter (CMS code)
# Pulmonary embolism, unspecified chronicity, unspecified pulmonary embolism type, unspecified whether acute cor pulmonale present (CMS code)
# Asthma with status asthmaticus, unspecified asthma severity, unspecified whether persistent
# Community acquired pneumonia, bilateral
# Perirectal abscess
# Abnormal finding on GI tract imaging
# Gluteal abscess
# Chronic pain after cancer treatment
# Scrotal edema
# Penile swelling
# Scrotal swelling
# Fournier's gangrene in male (CMS code)
# Assault
# Vision loss of right eye
# Central retinal artery occlusion of left eye
# Blurry vision, bilateral
# Undifferentiated schizophrenia (CMS code)
# Hallucination
# MVA (motor vehicle accident), initial encounter
# Laceration of scalp without foreign body, initial encounter
# Type 2 diabetes mellitus treated with insulin (CMS code)
# Localized swelling, mass or lump of neck
# Granuloma and granuloma-like lesions of oral mucosa
# Lip abscess
# Oropharyngeal mass
# Angioedema, initial encounter
# Spasm
# Generalized seizure (CMS code)
# Bleeding from throat
# Recurrent peritonsillar abscess
# Abnormal posture
# Facial pain
# Vision problem
# Transient vision disturbance
# Spontaneous intraparenchymal intracranial hemorrhage, acute (CMS code)
# Amaurosis fugax of right eye
# Right groin pain
# Perineal pain in male, chronic
# Aspiration pneumonia of lower lobe due to vomit (CMS code)
# Trigeminal neuralgia of left side of face
# Bowel perforation (CMS code)
# Insomnia, unspecified type
# Chronic ulcer of toe, unspecified laterality, unspecified ulcer stage (CMS code)
# Chronic left shoulder pain
# Involuntary movements
# Cirrhosis of liver with ascites, unspecified hepatic cirrhosis type (CMS code)
# Closed fracture of tooth, initial encounter
# Hypophosphatemia
# Binocular vision disorder with diplopia
# Glioma (CMS code)
# Vaginal cuff cellulitis
# Mild intermittent asthma with exacerbation
# Complex laceration of ear, right, initial encounter
# Vertebral artery disease (CMS code)
# Left-sided low back pain with left-sided sciatica, unspecified chronicity
# Retropharyngeal abscess
# Nephrotic syndrome
# Bloodstream infection associated with central venous catheter, initial encounter
# Odontogenic infection of jaw
# Otitis externa, unspecified chronicity, unspecified laterality, unspecified type
# Impacted stool in rectum (CMS code)
# Finger osteomyelitis (CMS code)
# Foot drop, right
# Decreased cardiac ejection fraction
# Hand fracture, right, closed, initial encounter
# Crushing injury of hand and fingers, right, initial encounter
# Gram-negative bacteremia
# Homelessness
# Cellulitis of right upper extremity
# Tibia/fibula fracture, shaft, unspecified laterality, closed, initial encounter
# DVT, lower extremity, recurrent, right (CMS code)
# Suicidal behavior with attempted self-injury (CMS code)
# Pain and swelling of left upper extremity
# Medical clearance for psychiatric admission
# Tinnitus, unspecified laterality
# Met CRPC pre-chemo (metastatic castrate-resistant adeno prostate cancer, pre-CRPC chemotherapy)  (CMS code)
# Orbital mass
# Otorrhea, right
# Open wound of lip, unspecified open wound type, initial encounter
# Fungal ear infection
# Malignant neoplasm of cervix, unspecified site (CMS code)
# Orbital floor (blow-out) closed fracture (CMS code)
# Infection of left olecranon bursa
# Delirium
# Palpable purpura (CMS code)
# Dysmenorrhea in adolescent
# Cellulitis and abscess of right leg
# Right foot ulcer, with unspecified severity (CMS code)
# Foreign body (FB) in soft tissue
# Epididymitis
# Alcohol withdrawal syndrome without complication (CMS code)
# Pyoderma gangrenosum (CMS code)
# Incarcerated left inguinal hernia
# Pre-operative examination
# Venous stasis dermatitis of both lower extremities
# VTE (venous thromboembolism)
# Sarcoidosis
# Right hand pain
# Migraine with vertigo
# Meningitis
# Foreign body sensation in throat
# Bleeding from shunt (CMS code)
# Neck discomfort
# Guillain Barré syndrome (CMS code)
# Accidental ingestion of substance, initial encounter
# Hidradenitis suppurativa
# Schizophreniform disorder (CMS code)
# Tailbone injury, initial encounter
# Neck abscess
# Encounter for management of wound VAC
# Malfunction of gastrostomy tube (CMS code)
# Diplopia
# Finger laceration, initial encounter
# Globus sensation
# Perinephric abscess
# Malignant neoplasm of colon, unspecified part of colon (CMS code)
# HCC (hepatocellular carcinoma) (CMS code)
# Accidental poisoning by psilocybin (CMS code)
# Type 1 diabetes mellitus with hyperglycemia (CMS code)
# Swelling of joint of right knee
# Recurrent oral ulcers
# Acute mastoiditis of left side
# Encounter for psychological evaluation
# Osteomyelitis due to Staphylococcus aureus (CMS code)
# Behavioral change
# Redness and swelling of upper arm
# Posterior dislocation of right shoulder joint, initial encounter
# Opioid withdrawal (CMS code)
# Blurred vision
# MVC (motor vehicle collision), initial encounter
# Mass of left parotid gland
# Skin flap infection
# Edema of optic disc of left eye
# Traumatic iritis
# Retained tampon, initial encounter
# Menorrhagia with irregular cycle
# Acute otitis externa of right ear, unspecified type
# AVM (congenital arteriovenous malformation)
# Vaginal pain
# Spinal cord tumor
# Biliary tube migration, initial encounter
# Post lumbar puncture headache
# Acute embolism and thrombosis of right internal jugular vein (CMS code)
# Ear canal abrasion, left, initial encounter
# Rectal pain
# Closed fracture of distal phalanx of lesser toe of right foot, initial encounter
# Acute left-sided low back pain with left-sided sciatica
# Psychosis, schizophrenia, simple (CMS code)
# Complication of feeding tube (CMS code)
# Closed fracture of sternum, initial encounter
# Wrist swelling, left
# Chronic bilateral lower abdominal pain
# Amputation stump infection (CMS code)
# Tracheo-esophageal fistula (CMS code)
# Spinal cord compression due to malignant neoplasm metastatic to spine (CMS code)
# Left arm pain
# Hypoventilation
# Laryngeal cancer (CMS code)
# Bicycle accident, initial encounter
# Anterior dislocation of left hip, sequela
# Effusion of right knee
# Normal exam
# Ekbom's delusional parasitosis (CMS code)
# Closed displaced oblique fracture of shaft of left humerus, initial encounter
# Acute drug intoxication with complication (CMS code)
# Left otitis media, unspecified otitis media type
# Contusion of head, initial encounter
# Ulcerative pancolitis (CMS code)
# Stimulant-induced psychotic disorder (CMS code)
# Partial thickness burn of left thigh, initial encounter
# Vaginitis affecting pregnancy in first trimester, antepartum
# Acute on chronic diastolic congestive heart failure (CMS code)
# Contact dermatitis, unspecified contact dermatitis type, unspecified trigger
# Bisphosphonate-associated osteonecrosis of the jaw (CMS code)
# Cancer (CMS code)
# Peritonitis (CMS code)
# Fracture of unspecified phalanx of left middle finger, initial encounter for open fracture
# PVD (peripheral vascular disease) (CMS code)
# Personal history of renal cell cancer
# Septic bursitis of elbow, left
# Food impaction of esophagus, subsequent encounter
# Laceration of head and neck, initial encounter
# Penile abscess
# Need for follow-up by social worker
# Pilonidal cyst with abscess
# Epididymitis, right
# Osteomyelitis, unspecified site, unspecified type (CMS code)
# Closed fracture of shaft of left femur with routine healing, unspecified fracture morphology, subsequent encounter
# Multiple sclerosis (CMS code)
# Acute pneumonia
# Scrotal infection
# Chronic pain syndrome
# History of acute lymphoblastic leukemia (ALL)
# Fracture of distal end of radius without additional fracture
# History of pulmonary embolus (PE)
# Status post deceased-donor kidney transplantation
# Hematoma of left breast
# History of pulmonary hypertension
# Prolonged QT interval
# Preseptal cellulitis of right eye
# Open wound of foot, right, sequela
# Spasticity
# Foot pain, right
# Creatinine elevation
# Blurry vision
# Squamous cell carcinoma in situ (SCCIS) of tongue
# Hearing loss, unspecified hearing loss type, unspecified laterality
# Ascites of liver
# Ambulatory dysfunction
# Tongue cancer (CMS code)
# Left wrist injury, initial encounter
# Allergic reaction, initial encounter
# Vaginal prolapse
# Facial abrasion, subsequent encounter
# Vascular dementia with agitation, unspecified dementia severity (CMS code)
# Fracture of left orbital wall (CMS code)
# Avulsion fracture
# Influenza-like illness
# Penile cellulitis
# Otalgia, unspecified laterality
# Tonsillar abscess
# Pharyngocutaneous fistula
# Incarcerated inguinal hernia
# Chronic ulcer of lower extremity, right, with unspecified severity (CMS code)
# Food impaction of esophagus, sequela
# Fracture of anterior arch of C1, closed, initial encounter (CMS code)
# Oculomotor nerve palsy, unspecified laterality
# SCC (squamous cell carcinoma)
# H/O tongue cancer
# Back spasm
# Jaw swelling
# Encounter for medication refill
# Shoulder dislocation, left, initial encounter
# Abdominal pain, suprapubic
# Left wrist pain
# Pain and swelling of left elbow
# Disseminated herpes zoster
# Abdominal wound dehiscence, initial encounter
# Intractable low back pain
# Diabetic foot ulcer with osteomyelitis (CMS code)
# Finger injury, right, initial encounter
# Pseudogout of left wrist
# Bite from dog, initial encounter
# Septic bursitis of elbow, right
# Ischemia of digits of hand
# Deep vein thrombosis (DVT) of left lower extremity, unspecified chronicity, unspecified vein (CMS code)
# Other post-procedural erectile dysfunction
# Visit for wound care
# Choking due to food (regurgitated), initial encounter
# Colostomy care (CMS code)
# Arrhythmogenic right ventricular cardiomyopathy (CMS code)
# Bleeding from open wound of chest wall, right, initial encounter
# Mouth ulcers
# Acute and subacute hepatic failure without coma
# Pyocele
# Recurrent spontaneous pneumothorax
# Spinal stenosis of lumbar region, unspecified whether neurogenic claudication present
# Humeral head fracture, right, with malunion, subsequent encounter
# Closed displaced Maisonneuve fracture, left, initial encounter
# Liver failure without hepatic coma, unspecified chronicity (CMS code)
# Moderate ankle sprain, initial encounter
# Hypo-osmolar hyponatremia
# Drug overdose, intentional self-harm, initial encounter (CMS code)
# Scalp laceration, initial encounter
# Intentional overdose of lamotrigine (CMS code)
# OSA on CPAP
# Food bolus obstruction of intestine (CMS code)
# Closed fracture of left wrist, initial encounter
# Congenital stenosis of lumbar spine
# Facial abscess
# Cognitive impairment
# Mediastinal mass
# Concussion with loss of consciousness, initial encounter
# Malignant biliary obstruction (CMS code)
# Dog bite, hand, right, initial encounter
# Decompensation of cirrhosis of liver (CMS code)
# Rib injury
# Possible exposure to STI
# Cord compression (CMS code)
# Vulvar edema
# Pain and swelling of knee, left
# Vaginal discharge
# Renal tubular acidosis type I
# Vision loss
# Cardiac cirrhosis
# Abscess of finger of left hand
# Ingrown toenail of both feet
# Aspiration into respiratory tract, initial encounter
# Toe injury, right, initial encounter
# Chronic gout due to renal impairment of multiple sites without tophus
# Amputation finger, initial encounter
# Wrist pain, acute, left
# Encounter for blood test
# Neuropathic pain
# Traumatic closed nondisplaced fracture of head of radius, left, initial encounter
# Laceration of forehead, initial encounter
# Ehlers-Danlos syndrome type III
# Displaced comminuted fracture of shaft of humerus, left arm, initial encounter for closed fracture
# Ankle pain, unspecified chronicity, unspecified laterality
# Ingestion of unknown medication, accidental or unintentional, initial encounter
# Pressure injury of skin of sacral region, unspecified injury stage
# Orbital cellulitis on right
# Knee injury, initial encounter
# Complaint associated with gastric tube (CMS code)
# Abscess of scalp
# History of stroke
# Other tracheostomy complication (CMS code)
# Incisional pain
# Multiple cerebral infarctions (CMS code)
# Infection of olecranon bursa, right
# Coagulation defect (CMS code)
# Posterior vitreous detachment, right
# Closed fracture of second toe of left foot, initial encounter
# Pilonidal cyst
# Dysphagia as late effect of cerebrovascular accident (CVA)
# Ulnar nerve compression, right
# Manic behavior (CMS code)
# Struck by raccoon, initial encounter
# Lip laceration, initial encounter
# Ischemic foot
# Orthostatic dizziness
# Heart block AV complete (CMS code)
# Acute deep vein thrombosis (DVT) of axillary vein of left upper extremity (CMS code)
# Influenza B
# Laceration of lower leg, complicated, right, initial encounter
# Thoracic spine tumor
# Superficial thrombophlebitis of right upper extremity
# Abnormal liver function tests
# End stage renal disease (CMS code)
# Bacterial vaginosis
# Spinal cord lesion (CMS code)
# Gangrenous (CMS code)
# Esophageal obstruction
# Spinal stenosis of lumbar region without neurogenic claudication
# Demyelinating disease (CMS code)
# Housing insecurity
# Chronic venous stasis
# Chondrosarcoma (CMS code)
# Pathological fracture of humerus due to neoplastic disease, initial encounter
# Delusion (CMS code)
# Bullous pemphigoid (CMS code)
# Mastitis
# Obstruction of ureter, unspecified laterality
# Dementia associated with other underlying disease, with agitation, unspecified dementia severity (CMS code)
# Embedded earring of right ear, initial encounter
# Hematoma of right buttock
# Nondisplaced fracture of first metatarsal bone, left foot, initial encounter for closed fracture
# Left shoulder pain, unspecified chronicity
# Adenocarcinoma (CMS code)
# Malignant neoplasm of liver, unspecified liver malignancy type (CMS code)
# Sprain of knee/leg, left, initial encounter
# Displaced fracture of distal end of fibula
# Facial tic
# Hand abscess
# Petechiae
# Odynophagia
# Expressive aphasia
# Respiratory distress
# Ingestion of toxic substance
# Withdrawal from benzodiazepine, with unspecified complication (CMS code)
# Tick bite of head, initial encounter
# Orbital wall fracture, closed, initial encounter (CMS code)
# Left buttock abscess
# Achilles tendonitis, bilateral
# Alzheimer disease (CMS code)
# Phlegmon
# Breast infection
# Bleeding gums
# AIDS (acquired immune deficiency syndrome) (CMS code)
# Intracranial hemorrhage (CMS code)
# Thigh laceration, right, initial encounter
# Leg laceration, right, initial encounter
# Cellulitis of left toe
# Mouth bleeding
# Cat bite of lower leg, right, initial encounter
# ICD (implantable cardioverter-defibrillator) discharge
# Cauda equina compression (CMS code)
# Acute otitis media, right
# Pruritus
# Tracheostomy complication, unspecified complication type (CMS code)
# Lower extremity dysfunction
# Closed displaced comminuted fracture of shaft of humerus, initial encounter
# Oral cancer (CMS code)
# Facial infection
# Animal bite of right hand with infection, initial encounter
# Cervical adenopathy
# ALS (amyotrophic lateral sclerosis) (CMS code)
# Calcific tendinitis
# Bicycle accident, injury, initial encounter
# Peripheral vascular disease of lower extremity (CMS code)
# Tylenol overdose, intentional self-harm, initial encounter (CMS code)
# Dog bite of knee, initial encounter
# Smoke inhalation
# Acute right lumbar radiculopathy
# Blistering rash
# Acute otitis externa of left ear, unspecified type
# Aneurysm of artery of arm (CMS code)
# Eating disorder, unspecified type
# Adult failure to thrive
# Oral infection
# Muscle strain of right lower leg, initial encounter

# %%
## Inputs: Chosen PMH, Age, Sex, Physical Exam (ED_presentation column), chief complaint
## Output: predicted diagnosis

# %%
import re
def extract_until_medical_decision(text):
    if pd.isna(text):
        return None
    # Split at first occurrence of "Medical Decision" (case-insensitive)
    parts = re.split(r'\bMedical Decision\b', text, flags=re.IGNORECASE)
    return parts[0].strip() if parts else None

# Apply it to the column
df['ED_Presentations'] = df['ED_Provider_Notes_Text'].apply(extract_until_medical_decision)

# %%
import pandas as pd
import os
import re
import json
import base64
import requests
import time
import urllib.parse

pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_colwidth', None)  # Set max column width to None
pd.set_option('display.width', None)  # Set width to None
# First, let's test by hard coding your Mulesoft Azure API key into the next line
API_KEY = 'x'  ##### Paste your API key between the quotes #####
API_VERSION = '2024-06-01'  # For the most recent production release: https://learn.microsoft.com/en-us/azure/ai-services/openai/api-version-deprecation#latest-ga-api-release
RESOURCE_ENDPOINT = 'https://unified-api.ucsf.edu/general'  # no trailing slash--this is used by libraries as a partial URL
DEPLOYMENT_NAME = "gpt-4o-2024-08-06"

# %%
def predict_diagnosis_with_dynamic_notes(row):
    # Extract all available fields
    chief_complaint = row['primarychiefcomplaintname']
    sex = row['sex']
    age = row['Age']
    presentation = row['ED_Presentations']
    
    # Check if necessary basic fields exist
    if pd.isna(chief_complaint):
        return None, None  # Skip if chief complaint is missing, return None for both prediction and requested notes
    
    # Initialize available note types with their existence status
    available_notes = {
        'Discharge Summary': not pd.isna(row.get('Discharge_Summary_Text')),
        'Progress Notes': not pd.isna(row.get('Progress_Note_Text')),
        'H&P': not pd.isna(row.get('HP_Note_Text')),
        'Echo': not pd.isna(row.get('Echo_Text')),
        'Imaging': not pd.isna(row.get('Imaging_Text')),
        'Consult': not pd.isna(row.get('Consult_Text')),
        'ECG': not pd.isna(row.get('ECG_Text')),
    }
    
    # Step 1: Ask the model which notes it wants to see (always include Discharge Summary if available)
    url = f"{RESOURCE_ENDPOINT}/openai/deployments/{DEPLOYMENT_NAME}/chat/completions?api-version={API_VERSION}"
    
    headers = {
        "Content-Type": "application/json",
        "api-key": API_KEY
    }
    
    # First message to decide which notes to read
    selection_payload = {
        "messages": [
            {"role": "system", "content": "You are an experienced Emergency Department (ED) physician. Your task is to decide which medical notes you need to read to predict the patient's ED diagnosis based on the chief complaint, PMH, physical exam findings, age, and sex."},
            {"role": "user", "content": f"Patient basic info: {age}yo {sex} with chief complaint: {chief_complaint}\n\n"
                                      f"Available notes (respond ONLY with the names of notes you want to see, separated by commas):\n"
                                      f"- Discharge Summary: {'Available' if available_notes['Discharge Summary'] else 'Not available'}\n"
                                      f"- Progress Notes: {'Available' if available_notes['Progress Notes'] else 'Not available'}\n"
                                      f"- H&P: {'Available' if available_notes['H&P'] else 'Not available'}\n"
                                      f"- Echo: {'Available' if available_notes['Echo'] else 'Not available'}\n"
                                      f"- Imaging: {'Available' if available_notes['Imaging'] else 'Not available'}\n"
                                      f"- Consult: {'Available' if available_notes['Consult'] else 'Not available'}\n"
                                      f"- ECG: {'Available' if available_notes['ECG'] else 'Not available'}\n"
                                      f"Based on the chief complaint, list ONLY the note types you need to review (comma-separated, no explanation). Always include Discharge Summary if available:"}
        ],
        "temperature": 0.1,
        "max_tokens": 1000
    }
    
    # Request note selection
    retries = 0
    requested_notes = []
    notes_requested_str = ""  # String to track requested notes
    
    while retries < 3:
        try:
            selection_response = requests.post(url, headers=headers, json=selection_payload)
            selection_response.raise_for_status()
            
            # Get requested note types
            notes_text = selection_response.json()["choices"][0]["message"]["content"].strip()
            requested_notes = [note.strip() for note in notes_text.split(',')]
            
            # Save the original request for the tracking column
            notes_requested_str = notes_text
            
            # Filter out unavailable notes
            requested_notes = [note for note in requested_notes 
                              if note in available_notes.keys() and available_notes[note]]
            
            # Always include Discharge Summary if available and not already requested
            if available_notes['Discharge Summary'] and 'Discharge Summary' not in requested_notes:
                requested_notes.append('Discharge Summary')
                if notes_requested_str:
                    notes_requested_str += ", Discharge Summary (auto-added)"
                else:
                    notes_requested_str = "Discharge Summary (auto-added)"
            
            break
        except requests.exceptions.RequestException as e:
            print(f"Note selection request failed: {e}. Retrying {retries+1}/3...")
            time.sleep(5)
            retries += 1
    
    if not requested_notes and available_notes['Discharge Summary']:
        # Default to discharge summary if selection failed but it's available
        requested_notes = ['Discharge Summary']
        notes_requested_str = "Failed to get selections. Defaulted to: Discharge Summary"
    elif not requested_notes:
        # If selection failed and no discharge summary, use whatever is available
        available_notes_list = [note for note, available in available_notes.items() if available][:2]
        requested_notes = available_notes_list
        notes_requested_str = f"Failed to get selections. Defaulted to: {', '.join(available_notes_list)}"
    
    # Step 2: Prepare the actual notes content
    notes_content = ""
    
    # Map note types to DataFrame column names
    note_type_to_column = {
        'Discharge Summary': 'Discharge_Summary_Text',
        'Progress Notes': 'Progress_Note_Text',
        'H&P': 'HP_Note_Text',
        'Echo': 'Echo_Text',
        'Imaging': 'Imaging_Text',
        'Consult': 'Consult_Text',
        'ECG': 'ECG_Text',
    }
    
    # Function to truncate text to manage token limits
    def truncate_text(text, max_chars=3000):
        if text and len(text) > max_chars:
            return text[:max_chars] + "..."
        return text
    
    # Add requested notes to content, with truncation
    for note_type in requested_notes:
        column_name = note_type_to_column.get(note_type)
        if column_name and not pd.isna(row.get(column_name)):
            notes_content += f"\n\n{note_type}:\n{truncate_text(row[column_name])}"
    
    # Step 3: Generate the diagnosis prediction
    prediction_payload = {
        "messages": [
            {"role": "system", "content": "You are an experienced Emergency Department (ED) physician tasked with predicting the most likely diagnosis for a patient based on their presentation, chief complaint, and available medical information."},
            {"role": "user", "content": f"Based on the patient's chief complaint, age, sex, and available clinical information, predict the most likely ED diagnosis. Provide a single diagnosis for the CURRENT ED Visit from the standardized CMS codes without explanation but with the word, not the code.\n\n"
                                      f"Chief Complaint: {chief_complaint}\n"
                                      f"Age: {age}\n"
                                      f"Sex: {sex}\n"
                                      f"Current ED Presentation: {presentation}\n"
                                      f"{notes_content}"}
        ],
        "temperature": 0.1,
        "max_tokens": 6000
    }
    
    # Request the diagnosis prediction
    retries = 0
    while retries < 3:
        try:
            prediction_response = requests.post(url, headers=headers, json=prediction_payload)
            prediction_response.raise_for_status()
            return prediction_response.json()["choices"][0]["message"]["content"].strip(), notes_requested_str
        except requests.exceptions.RequestException as e:
            print(f"Prediction request failed: {e}. Retrying {retries+1}/3...")
            time.sleep(5)
            retries += 1
    
    return None, notes_requested_str  # Return None for prediction and the requested notes string if all retries fail

# Apply function to DataFrame - now returns two values (prediction and requested notes)
results = df.apply(lambda row: predict_diagnosis_with_dynamic_notes(row), axis=1)

# Split the results into two columns
df["Predicted_Diagnosis"] = [result[0] for result in results]
df["Requested_Notes"] = [result[1] for result in results]

# Add column to track accuracy of prediction
df["Prediction_Correct"] = df["Predicted_Diagnosis"] == df["primaryeddiagnosisname"]

# Calculate overall accuracy
accuracy = (df["Prediction_Correct"].sum() / df["Prediction_Correct"].count()) * 100
print(f"Overall prediction accuracy: {accuracy:.2f}%")

# Save to CSV and Display
df.to_csv("ed_diagnosis_predictions.csv", index=False)
# Out:
# Overall prediction accuracy: 4.67%

# %%
df.loc[:,['Age','primaryeddiagnosisname','Predicted_Diagnosis']]
# Out:
#     Age                    primaryeddiagnosisname        Predicted_Diagnosis
# 0    88                      CAD in native artery  Abdominal Aortic Aneurysm
# 1    71                            Vesicular rash                    Ascites
# 2    49  SBO (small bowel obstruction) (CMS code)    Small bowel obstruction
# 3    58                          Gastroduodenitis              Gastric ulcer
# 4    55              Nausea vomiting and diarrhea     Afferent loop syndrome
# 5    82                            Abdominal pain                  Cirrhosis
# 6    69                      Acute abdominal pain                    Colitis
# 7    48                     Chronic cholecystitis              Cholecystitis
# 8    57                            Abdominal pain     Hepatic encephalopathy
# 9    56                      Acute abdominal pain             Carcinomatosis
# 10   41                Generalized abdominal pain             Pelvic abscess
# 11   56   Cellulitis, unspecified cellulitis site                 Cellulitis
# 12   57                Generalized abdominal pain          Shunt malfunction
# 13   45                Generalized abdominal pain      Crohn's disease flare
# 14   83      Cholelithiasis without cholecystitis             Cholelithiasis
