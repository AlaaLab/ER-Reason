# %%
import pandas as pd
from rouge_score import rouge_scorer
import re
import six 

df = pd.read_csv('new_4o_ehr_review.csv')
df2 = pd.read_csv('35_ehr_review.csv')
df3 = pd.read_csv('o3_ehr_review.csv')
df4 = pd.read_csv('llama3_ehr.csv')

# %%
import re

def process_text(text):
    text = text.lower()
    text = re.sub(r"[^a-z0-9\s]", "", text)
    tokens = text.split()
    return tokens

def lcs(X, Y):
    m, n = len(X), len(Y)
    dp = [[0]*(n+1) for _ in range(m+1)]
    for i in range(m):
        for j in range(n):
            if X[i] == Y[j]:
                dp[i+1][j+1] = dp[i][j] + 1
            else:
                dp[i+1][j+1] = max(dp[i][j+1], dp[i+1][j])
    return dp[m][n]

def rouge_l_recall(pred, ref):
    pred_tokens = process_text(pred)
    ref_tokens = process_text(ref)
    if not ref_tokens:
        return 0.0
    lcs_len = lcs(pred_tokens, ref_tokens)
    return lcs_len / len(ref_tokens)

# Example usage:
generated_text = "61 y.o. female with a history of recurrent SBO s/p 07/26/20, severe PCM with GT feeding, pancreatic insufficiency, MCA aneurysm s/p clip/shunt, seizure disorder on 4AEDS, HTN, IDDM, COPD, and previous polysubstance abuse presenting with shortness of breath."
reference_text = "***** ***** is a ***** y.o. old female, with history of COPD, aspiration, CVA, Gtube, T2DM, seizure disorder, ***** as code 3 for respiratory distress"

score = rouge_l_recall(generated_text, reference_text)
print(f"ROUGE-L recall: {score:.4f}")
# Out:
# ROUGE-L recall: 0.3333

# %%
from collections import Counter

def get_ngrams(tokens, n):
    return [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]

def rouge_n_recall(pred_text, ref_text, n=1):
    pred_tokens = pred_text.split()
    ref_tokens = ref_text.split()
    
    pred_ngrams = Counter(get_ngrams(pred_tokens, n))
    ref_ngrams = Counter(get_ngrams(ref_tokens, n))
    
    # Count overlap
    overlap = 0
    for ng in ref_ngrams:
        overlap += min(ref_ngrams[ng], pred_ngrams.get(ng, 0))
    
    total_ref_ngrams = sum(ref_ngrams.values())
    
    if total_ref_ngrams == 0:
        return 0.0
    return overlap / total_ref_ngrams

# Example usage:
generated_text = "61 y.o. female with a history of recurrent SBO s/p 07/26/20, severe PCM with GT feeding, pancreatic insufficiency, MCA aneurysm s/p clip/shunt, seizure disorder on 4AEDS, HTN, IDDM, COPD, and previous polysubstance abuse presenting with shortness of breath."
reference_text = "***** ***** is a ***** y.o. old female, with history of COPD, aspiration, CVA, Gtube, T2DM, seizure disorder, ***** as code 3 for respiratory distress"

rouge_1 = rouge_n_recall(generated_text, reference_text, n=1)
rouge_2 = rouge_n_recall(generated_text, reference_text, n=2)

print(f"ROUGE-1 recall: {rouge_1:.4f}")
print(f"ROUGE-2 recall: {rouge_2:.4f}")
# Out:
# ROUGE-1 recall: 0.2800
# ROUGE-2 recall: 0.0417

# %%
import pandas as pd
from evaluate import load

# Example DataFrame
df = pd.DataFrame({
    'generated_text': [
        "61 y.o. female with a history of recurrent SBO s/p 07/26/20, severe PCM with GT feeding, pancreatic insufficiency, MCA aneurysm s/p clip/shunt, seizure disorder on 4AEDS, HTN, IDDM, COPD, and previous polysubstance abuse presenting with shortness of breath."
    ],
    'reference_text': [ 
        "***** ***** is a ***** y.o. old female, with history of COPD, aspiration, CVA, Gtube, T2DM, seizure disorder, ***** as code 3 for respiratory distress"
    ]
})

# Optionally remove placeholder asterisks
def clean(text):
    return text.replace("*****", "").strip()

# Load ROUGE metric
rouge = load("rouge")

# Function to calculate ROUGE-L score
def compute_rouge_l(pred, ref):
    result = rouge.compute(predictions=[pred], references=[ref], use_aggregator=False)
    return result["rougeL"][0]

# Clean text (optional)
df["clean_pred"] = df["generated_text"].apply(clean)
df["clean_ref"] = df["reference_text"].apply(clean)

# Apply ROUGE-L row-wise
df["rougeL"] = df.apply(lambda row: compute_rouge_l(row["clean_pred"], row["clean_ref"]), axis=1)

# Output
print(df[["generated_text", "reference_text", "rougeL"]])

# %%
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'])

# %%
df["Generated_Summary"].isna().sum()
# Out:
# 0

# %%
df2 = df2.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'])
df2
# Out:
#      patientdurablekey    encounterkey  ArrivalDateKey DepartureDateKeyValue  \
# 0       DD644159F63417  D97E95EF247E4C        20230710            2023-07-11
# 1       D76477E56C0B53  D70EAC2389B921        20221202            2022-12-04
# 2       D76477E56C0B53  D0D09A7E783F07        20240106            2024-01-08
# 3       D8F7D48FAEB29D  D486E6DF6FE817        20230205            2023-02-06
# 4       D8F7D48FAEB29D  DA51A78587E4AC        20230427            2023-04-28
# ...                ...             ...             ...                   ...
# 3979    D747CBD26BF2E5  D7B93BB4215531        20240202            2024-02-03
# 3980    D8425274DB07BA  D88975CFC960BD        20220620            2022-06-21
# 3981    D747CBD26BF2E5  D0B1EF59F6B2DF        20220720            2022-07-21
# 3982    D9D86E0714A5B5  DC740569C682A9        20230811            2023-08-12
# 3983    D18B56824244B0  DB61597D83965C        20240103            2024-01-04
#
#       DepartureDateKey DispositionDateKeyValue primarychiefcomplaintname  \
# 0             20230711              2023-07-11       SHORTNESS OF BREATH
# 1             20221204              2022-12-03                      FALL
# 2             20240108              2024-01-06             MOUTH LESIONS
# 3             20230206              2023-02-06                 HEMATURIA
# 4             20230428              2023-04-28          VAGINAL BLEEDING
# ...                ...                     ...                       ...
# 3979          20240203              2024-02-03            ABDOMINAL PAIN
# 3980          20220621              2022-06-20            ABDOMINAL PAIN
# 3981          20220721              2022-07-20                     OTHER
# 3982          20230812              2023-08-12                ARM INJURY
# 3983          20240104              2024-01-04           POST-OP PROBLEM
#
#                                  primaryeddiagnosisname     sex   birthdate  \
# 0                                               Hypoxia  Female  1961-08-23
# 1                                Fall from ground level  Female  1970-12-12
# 2     AIDS (acquired immune deficiency syndrome) (CM...  Female  1970-12-12
# 3                                        Pyelonephritis  Female  1996-10-14
# 4               PID (acute pelvic inflammatory disease)  Female  1996-10-14
# ...                                                 ...     ...         ...
# 3979                               Bilateral flank pain  Female  2002-10-26
# 3980  Ulcerative colitis with complication, unspecif...  Female  2002-02-09
# 3981          Complicated UTI (urinary tract infection)  Female  2002-10-26
# 3982   Closed fracture of left wrist, initial encounter  Female  1966-12-26
# 3983                                          Neck pain    Male  1974-12-28
#
#       ...                                          Echo_Text  \
# 0     ...                                                NaN
# 1     ...  \n\nPatient Name: ***** *****        Patient I...
# 2     ...  \n\nPatient Name: ***** *****        Patient I...
# 3     ...  University of *****,                          ...
# 4     ...  University of *****,                          ...
# ...   ...                                                ...
# 3979  ...  University of *****,                          ...
# 3980  ...                                                NaN
# 3981  ...  University of *****,                          ...
# 3982  ...  \n\nTRANSTHORACIC ECHOCARDIOGRAM"\n\n\n\nPatie...
# 3983  ...                                                NaN
#
#                                            Imaging_Text  \
# 0     CT ANGIO BRAIN/NECK FOR STROKE (INC 3D POST-PR...
# 1     XR CHEST 2 VIEWS PA AND LATERAL   06/08/2017 3...
# 2     XR CHEST 1 VIEW *****   01/08/2023 4:20 PM"\n\...
# 3     XR ANKLE 3 VIEWS, LEFT   11/23/2020 5:21 PM   ...
# 4     XR ANKLE 3 VIEWS, LEFT   11/23/2020 5:21 PM   ...
# ...                                                 ...
# 3979  CT ABDOMEN/PELVIS WITH AND WITHOUT CONTRAST   ...
# 3980  XR ABDOMEN COMPLETE   09/05/2020 5:15 AM    IN...
# 3981  CT ABDOMEN/PELVIS WITH AND WITHOUT CONTRAST   ...
# 3982  IMPRESSION:     SIZES AND DATES  CLINICAL HIST...
# 3983  '\n Study type: Frontal and lateral images of ...
#
#                                            Consult_Text  \
# 0     ***** *****. *****, RN     04/16/2022  1:12 PM...
# 1     ***** ***** *****, MD     12/04/2022  4:22 PM"...
# 2     ***** ***** *****, MD     12/04/2022  4:22 PM"...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3979  ***** *****, MD     09/24/2018  5:48 PM"\n\n\n...
# 3980  ***** *****     07/29/2018  6:43 PM"\n\nIBD (u...
# 3981  ***** *****, MD     09/24/2018  5:48 PM"\n\n\n...
# 3982  UNIVERSITY ***** *****, ***** *****"\n\nCLINIC...
# 3983                                                NaN
#
#                                                ECG_Text  \
# 0     IMPRESSION:   Borderline ECG  Sinus tachycardi...
# 1     IMPRESSION:   Normal sinus rhythm  Possible La...
# 2     IMPRESSION:   Normal sinus rhythm  Possible La...
# 3                                                   NaN
# 4     IMPRESSION:   Normal sinus rhythm with sinus a...
# ...                                                 ...
# 3979  Normal sinus rhythm"\n\nPrecordial lead mispla...
# 3980  Borderline ECG"\n\nSinus tachycardia"\n\nWhen ...
# 3981  Normal sinus rhythm"\n\nPrecordial lead mispla...
# 3982  EKG  #       DATE:  02/09/02, 5:26 pm         ...
# 3983                                                NaN
#
#                                  ED_Provider_Notes_Text  \
# 0     EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# 1     EMERGENCY DEPARTMENT PHYSICIAN NOTE        ED ...
# 2     EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# 3     EMERGENCY DEPARTMENT PHYSICIAN NOTE        ED ...
# 4     EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# ...                                                 ...
# 3979  EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# 3980  EMERGENCY DEPARTMENT PHYSICIAN NOTE        ED ...
# 3981  EMERGENCY DEPARTMENT PHYSICIAN NOTE        ED ...
# 3982  EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# 3983  EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
#
#                                  One_Sentence_Extracted note_count  \
# 0     ***** ***** is a ***** y.o. old female, with h...          7
# 1     ***** ***** is a ***** y.o. old female, who ha...          8
# 2     ***** ***** is a ***** y.o. old female, with A...          8
# 3     ***** ***** ***** ***** is a ***** y.o. old fe...          6
# 4     ***** ***** ***** ***** is a ***** y.o. old fe...          7
# ...                                                 ...        ...
# 3979  ***** is a ***** y.o. old female, with lupus c...          8
# 3980  ***** ***** is a ***** y.o. old female, with P...          7
# 3981  ***** is a ***** y.o. old female, with a PMH w...          8
# 3982  ***** ***** is a ***** y.o. old female, with s...          8
# 3983  ***** ***** is a ***** y.o. old male, with cer...          5
#
#       acuitylevel eddisposition  \
# 0       Immediate         Admit
# 1          Urgent         Admit
# 2     Less Urgent         Admit
# 3          Urgent     Discharge
# 4          Urgent     Discharge
# ...           ...           ...
# 3979          NaN           NaN
# 3980          NaN           NaN
# 3981          NaN           NaN
# 3982          NaN           NaN
# 3983          NaN           NaN
#
#                                       Generated_Summary
# 0     61-year-old female with history of recurrent S...
# 1     51-year-old female with h/o active crack and I...
# 2     53-year-old female with h/o active crack and I...
# 3     26-year-old female, G1P0 with NSVD, postpartum...
# 4     26-year-old female, G1P0 with NSVD on 06/12/20...
# ...                                                 ...
# 3979  21-year-old female with a history of discharge...
# 3980  20 y.o. female with history of ulcerative coli...
# 3981  19-year-old female with unremarkable past medi...
# 3982  56-year-old female with a history of seizure d...
# 3983  49-year-old male with a history of cervical ra...
#
# [3984 rows x 44 columns]

# %%
df2["Generated_Summary"].isna().sum()
# Out:
# 17

# %%
df3 = df3.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'])
df3
# Out:
#      patientdurablekey    encounterkey  ArrivalDateKey DepartureDateKeyValue  \
# 0       DD644159F63417  D97E95EF247E4C        20230710            2023-07-11
# 1       D76477E56C0B53  D70EAC2389B921        20221202            2022-12-04
# 2       D76477E56C0B53  D0D09A7E783F07        20240106            2024-01-08
# 3       D8F7D48FAEB29D  D486E6DF6FE817        20230205            2023-02-06
# 4       D8F7D48FAEB29D  DA51A78587E4AC        20230427            2023-04-28
# ...                ...             ...             ...                   ...
# 3979    D747CBD26BF2E5  D7B93BB4215531        20240202            2024-02-03
# 3980    D8425274DB07BA  D88975CFC960BD        20220620            2022-06-21
# 3981    D747CBD26BF2E5  D0B1EF59F6B2DF        20220720            2022-07-21
# 3982    D9D86E0714A5B5  DC740569C682A9        20230811            2023-08-12
# 3983    D18B56824244B0  DB61597D83965C        20240103            2024-01-04
#
#       DepartureDateKey DispositionDateKeyValue primarychiefcomplaintname  \
# 0             20230711              2023-07-11       SHORTNESS OF BREATH
# 1             20221204              2022-12-03                      FALL
# 2             20240108              2024-01-06             MOUTH LESIONS
# 3             20230206              2023-02-06                 HEMATURIA
# 4             20230428              2023-04-28          VAGINAL BLEEDING
# ...                ...                     ...                       ...
# 3979          20240203              2024-02-03            ABDOMINAL PAIN
# 3980          20220621              2022-06-20            ABDOMINAL PAIN
# 3981          20220721              2022-07-20                     OTHER
# 3982          20230812              2023-08-12                ARM INJURY
# 3983          20240104              2024-01-04           POST-OP PROBLEM
#
#                                  primaryeddiagnosisname     sex   birthdate  \
# 0                                               Hypoxia  Female  1961-08-23
# 1                                Fall from ground level  Female  1970-12-12
# 2     AIDS (acquired immune deficiency syndrome) (CM...  Female  1970-12-12
# 3                                        Pyelonephritis  Female  1996-10-14
# 4               PID (acute pelvic inflammatory disease)  Female  1996-10-14
# ...                                                 ...     ...         ...
# 3979                               Bilateral flank pain  Female  2002-10-26
# 3980  Ulcerative colitis with complication, unspecif...  Female  2002-02-09
# 3981          Complicated UTI (urinary tract infection)  Female  2002-10-26
# 3982   Closed fracture of left wrist, initial encounter  Female  1966-12-26
# 3983                                          Neck pain    Male  1974-12-28
#
#       ...                                          Echo_Text  \
# 0     ...                                                NaN
# 1     ...  \n\nPatient Name: ***** *****        Patient I...
# 2     ...  \n\nPatient Name: ***** *****        Patient I...
# 3     ...  University of *****,                          ...
# 4     ...  University of *****,                          ...
# ...   ...                                                ...
# 3979  ...  University of *****,                          ...
# 3980  ...                                                NaN
# 3981  ...  University of *****,                          ...
# 3982  ...  \n\nTRANSTHORACIC ECHOCARDIOGRAM"\n\n\n\nPatie...
# 3983  ...                                                NaN
#
#                                            Imaging_Text  \
# 0     CT ANGIO BRAIN/NECK FOR STROKE (INC 3D POST-PR...
# 1     XR CHEST 2 VIEWS PA AND LATERAL   06/08/2017 3...
# 2     XR CHEST 1 VIEW *****   01/08/2023 4:20 PM"\n\...
# 3     XR ANKLE 3 VIEWS, LEFT   11/23/2020 5:21 PM   ...
# 4     XR ANKLE 3 VIEWS, LEFT   11/23/2020 5:21 PM   ...
# ...                                                 ...
# 3979  CT ABDOMEN/PELVIS WITH AND WITHOUT CONTRAST   ...
# 3980  XR ABDOMEN COMPLETE   09/05/2020 5:15 AM    IN...
# 3981  CT ABDOMEN/PELVIS WITH AND WITHOUT CONTRAST   ...
# 3982  IMPRESSION:     SIZES AND DATES  CLINICAL HIST...
# 3983  '\n Study type: Frontal and lateral images of ...
#
#                                            Consult_Text  \
# 0     ***** *****. *****, RN     04/16/2022  1:12 PM...
# 1     ***** ***** *****, MD     12/04/2022  4:22 PM"...
# 2     ***** ***** *****, MD     12/04/2022  4:22 PM"...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3979  ***** *****, MD     09/24/2018  5:48 PM"\n\n\n...
# 3980  ***** *****     07/29/2018  6:43 PM"\n\nIBD (u...
# 3981  ***** *****, MD     09/24/2018  5:48 PM"\n\n\n...
# 3982  UNIVERSITY ***** *****, ***** *****"\n\nCLINIC...
# 3983                                                NaN
#
#                                                ECG_Text  \
# 0     IMPRESSION:   Borderline ECG  Sinus tachycardi...
# 1     IMPRESSION:   Normal sinus rhythm  Possible La...
# 2     IMPRESSION:   Normal sinus rhythm  Possible La...
# 3                                                   NaN
# 4     IMPRESSION:   Normal sinus rhythm with sinus a...
# ...                                                 ...
# 3979  Normal sinus rhythm"\n\nPrecordial lead mispla...
# 3980  Borderline ECG"\n\nSinus tachycardia"\n\nWhen ...
# 3981  Normal sinus rhythm"\n\nPrecordial lead mispla...
# 3982  EKG  #       DATE:  02/09/02, 5:26 pm         ...
# 3983                                                NaN
#
#                                  ED_Provider_Notes_Text  \
# 0     EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# 1     EMERGENCY DEPARTMENT PHYSICIAN NOTE        ED ...
# 2     EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# 3     EMERGENCY DEPARTMENT PHYSICIAN NOTE        ED ...
# 4     EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# ...                                                 ...
# 3979  EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# 3980  EMERGENCY DEPARTMENT PHYSICIAN NOTE        ED ...
# 3981  EMERGENCY DEPARTMENT PHYSICIAN NOTE        ED ...
# 3982  EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# 3983  EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
#
#                                  One_Sentence_Extracted note_count  \
# 0     ***** ***** is a ***** y.o. old female, with h...          7
# 1     ***** ***** is a ***** y.o. old female, who ha...          8
# 2     ***** ***** is a ***** y.o. old female, with A...          8
# 3     ***** ***** ***** ***** is a ***** y.o. old fe...          6
# 4     ***** ***** ***** ***** is a ***** y.o. old fe...          7
# ...                                                 ...        ...
# 3979  ***** is a ***** y.o. old female, with lupus c...          8
# 3980  ***** ***** is a ***** y.o. old female, with P...          7
# 3981  ***** is a ***** y.o. old female, with a PMH w...          8
# 3982  ***** ***** is a ***** y.o. old female, with s...          8
# 3983  ***** ***** is a ***** y.o. old male, with cer...          5
#
#       acuitylevel eddisposition  \
# 0       Immediate         Admit
# 1          Urgent         Admit
# 2     Less Urgent         Admit
# 3          Urgent     Discharge
# 4          Urgent     Discharge
# ...           ...           ...
# 3979          NaN           NaN
# 3980          NaN           NaN
# 3981          NaN           NaN
# 3982          NaN           NaN
# 3983          NaN           NaN
#
#                                       Generated_Summary
# 0     61 y.o. female with h/o recurrent SBO s/p 07/2...
# 1     51 y/o female with past history of AIDS (CD4 8...
# 2     53 y.o. f, with h/o AIDS (advanced HIV with CD...
# 3     26 y.o. female with hx of normal labor with ep...
# 4     26 y.o. female with h/o normal spontaneous vag...
# ...                                                 ...
# 3979  21 y.o. female with a past ED visit on 08/04/2...
# 3980  20 y.o. female with h/o ulcerative colitis wit...
# 3981  19 y.o. female with previous ED encounter on 0...
# 3982  56 y.o. female with history of seizure disorde...
# 3983  49 y.o. male with past history of cervical rad...
#
# [3984 rows x 44 columns]

# %%
df3["Generated_Summary"].isna().sum()
# Out:
# 0

# %%
df4 = df4.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-9dccac391167> in <module>
# ----> 1 df4 = df4.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'])
#       2 df4["Assistant_Content"]
#
# ~/virtual_environments/text/lib64/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# ~/virtual_environments/text/lib64/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ~/virtual_environments/text/lib64/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3921                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3922             else:
# -> 3923                 new_axis = axis.drop(labels, errors=errors)
#    3924             result = self.reindex(**{axis_name: new_axis})
#    3925
#
# ~/virtual_environments/text/lib64/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5285         if mask.any():
#    5286             if errors != "ignore":
# -> 5287                 raise KeyError(f"{labels[mask]} not found in axis")
#    5288             indexer = indexer[~mask]
#    5289         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0' 'Unnamed: 0.1' 'Unnamed: 0.1.1'] not found in axis"

# %%
df4["Assistant_Content"].isna().sum()
# Out:
# 0

# %%
df4["Assistant_Content"][4]
# Out:
# '\n\n26 y.o. female, with h/o G1P1, previous normal labor and delivery, epidural, 2nd degree perineal laceration, postpartum course: normal, no pending tests or complications, and currently presenting with vaginal bleeding.'

# %%
df4
# Out:
#       Unnamed: 0.2 patientdurablekey    encounterkey  ArrivalDateKey  \
# 0                0    DD644159F63417  D97E95EF247E4C        20230710
# 1                1    D76477E56C0B53  D70EAC2389B921        20221202
# 2                2    D76477E56C0B53  D0D09A7E783F07        20240106
# 3                3    D8F7D48FAEB29D  D486E6DF6FE817        20230205
# 4                4    D8F7D48FAEB29D  DA51A78587E4AC        20230427
# ...            ...               ...             ...             ...
# 3979          3979    D747CBD26BF2E5  D7B93BB4215531        20240202
# 3980          3980    D8425274DB07BA  D88975CFC960BD        20220620
# 3981          3981    D747CBD26BF2E5  D0B1EF59F6B2DF        20220720
# 3982          3982    D9D86E0714A5B5  DC740569C682A9        20230811
# 3983          3983    D18B56824244B0  DB61597D83965C        20240103
#
#      DepartureDateKeyValue  DepartureDateKey DispositionDateKeyValue  \
# 0               2023-07-11          20230711              2023-07-11
# 1               2022-12-04          20221204              2022-12-03
# 2               2024-01-08          20240108              2024-01-06
# 3               2023-02-06          20230206              2023-02-06
# 4               2023-04-28          20230428              2023-04-28
# ...                    ...               ...                     ...
# 3979            2024-02-03          20240203              2024-02-03
# 3980            2022-06-21          20220621              2022-06-20
# 3981            2022-07-21          20220721              2022-07-20
# 3982            2023-08-12          20230812              2023-08-12
# 3983            2024-01-04          20240104              2024-01-04
#
#      primarychiefcomplaintname  \
# 0          SHORTNESS OF BREATH
# 1                         FALL
# 2                MOUTH LESIONS
# 3                    HEMATURIA
# 4             VAGINAL BLEEDING
# ...                        ...
# 3979            ABDOMINAL PAIN
# 3980            ABDOMINAL PAIN
# 3981                     OTHER
# 3982                ARM INJURY
# 3983           POST-OP PROBLEM
#
#                                  primaryeddiagnosisname     sex  ...  \
# 0                                               Hypoxia  Female  ...
# 1                                Fall from ground level  Female  ...
# 2     AIDS (acquired immune deficiency syndrome) (CM...  Female  ...
# 3                                        Pyelonephritis  Female  ...
# 4               PID (acute pelvic inflammatory disease)  Female  ...
# ...                                                 ...     ...  ...
# 3979                               Bilateral flank pain  Female  ...
# 3980  Ulcerative colitis with complication, unspecif...  Female  ...
# 3981          Complicated UTI (urinary tract infection)  Female  ...
# 3982   Closed fracture of left wrist, initial encounter  Female  ...
# 3983                                          Neck pain    Male  ...
#
#                                            Imaging_Text  \
# 0     CT ANGIO BRAIN/NECK FOR STROKE (INC 3D POST-PR...
# 1     XR CHEST 2 VIEWS PA AND LATERAL   06/08/2017 3...
# 2     XR CHEST 1 VIEW *****   01/08/2023 4:20 PM"\n\...
# 3     XR ANKLE 3 VIEWS, LEFT   11/23/2020 5:21 PM   ...
# 4     XR ANKLE 3 VIEWS, LEFT   11/23/2020 5:21 PM   ...
# ...                                                 ...
# 3979  CT ABDOMEN/PELVIS WITH AND WITHOUT CONTRAST   ...
# 3980  XR ABDOMEN COMPLETE   09/05/2020 5:15 AM    IN...
# 3981  CT ABDOMEN/PELVIS WITH AND WITHOUT CONTRAST   ...
# 3982  IMPRESSION:     SIZES AND DATES  CLINICAL HIST...
# 3983  '\n Study type: Frontal and lateral images of ...
#
#                                            Consult_Text  \
# 0     ***** *****. *****, RN     04/16/2022  1:12 PM...
# 1     ***** ***** *****, MD     12/04/2022  4:22 PM"...
# 2     ***** ***** *****, MD     12/04/2022  4:22 PM"...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3979  ***** *****, MD     09/24/2018  5:48 PM"\n\n\n...
# 3980  ***** *****     07/29/2018  6:43 PM"\n\nIBD (u...
# 3981  ***** *****, MD     09/24/2018  5:48 PM"\n\n\n...
# 3982  UNIVERSITY ***** *****, ***** *****"\n\nCLINIC...
# 3983                                                NaN
#
#                                                ECG_Text  \
# 0     IMPRESSION:   Borderline ECG  Sinus tachycardi...
# 1     IMPRESSION:   Normal sinus rhythm  Possible La...
# 2     IMPRESSION:   Normal sinus rhythm  Possible La...
# 3                                                   NaN
# 4     IMPRESSION:   Normal sinus rhythm with sinus a...
# ...                                                 ...
# 3979  Normal sinus rhythm"\n\nPrecordial lead mispla...
# 3980  Borderline ECG"\n\nSinus tachycardia"\n\nWhen ...
# 3981  Normal sinus rhythm"\n\nPrecordial lead mispla...
# 3982  EKG  #       DATE:  02/09/02, 5:26 pm         ...
# 3983                                                NaN
#
#                                  ED_Provider_Notes_Text  \
# 0     EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# 1     EMERGENCY DEPARTMENT PHYSICIAN NOTE        ED ...
# 2     EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# 3     EMERGENCY DEPARTMENT PHYSICIAN NOTE        ED ...
# 4     EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# ...                                                 ...
# 3979  EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# 3980  EMERGENCY DEPARTMENT PHYSICIAN NOTE        ED ...
# 3981  EMERGENCY DEPARTMENT PHYSICIAN NOTE        ED ...
# 3982  EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
# 3983  EMERGENCY DEPARTMENT PHYSICIAN NOTE      ED At...
#
#                                  One_Sentence_Extracted  note_count  \
# 0     ***** ***** is a ***** y.o. old female, with h...           7
# 1     ***** ***** is a ***** y.o. old female, who ha...           8
# 2     ***** ***** is a ***** y.o. old female, with A...           8
# 3     ***** ***** ***** ***** is a ***** y.o. old fe...           6
# 4     ***** ***** ***** ***** is a ***** y.o. old fe...           7
# ...                                                 ...         ...
# 3979  ***** is a ***** y.o. old female, with lupus c...           8
# 3980  ***** ***** is a ***** y.o. old female, with P...           7
# 3981  ***** is a ***** y.o. old female, with a PMH w...           8
# 3982  ***** ***** is a ***** y.o. old female, with s...           8
# 3983  ***** ***** is a ***** y.o. old male, with cer...           5
#
#       acuitylevel eddisposition  \
# 0       Immediate         Admit
# 1          Urgent         Admit
# 2     Less Urgent         Admit
# 3          Urgent     Discharge
# 4          Urgent     Discharge
# ...           ...           ...
# 3979          NaN           NaN
# 3980          NaN           NaN
# 3981          NaN           NaN
# 3982          NaN           NaN
# 3983          NaN           NaN
#
#                                       Assistant_Content  \
# 0     80 y.o. female, with h/o HFpEF (EF 55-60% 05/2...
# 1     51 y/o female with h/o PSA (active crack and I...
# 2     "53 y/o female with h/o HIV (10/2015 CD4 246k,...
# 3     26 y.o. female with h/o hypertension, HLD, bip...
# 4     26 y.o. female, with h/o G1P1, previous normal...
# ...                                                 ...
# 3979  Here's a concise one-liner summary for the pat...
# 3980  20 y.o. female, with a history of ulcerative c...
# 3981  19 y/o female, with h/o of asthma, depression,...
# 3982  56 y/o female, with h/o seizure disorder (Lami...
# 3983  49 y.o. male, h/o HFpEF, HTN, HLD, and bipolar...
#
#                        Processed_One_Sentence_Extracted
# 0      is a y o old female with history of copd aspi...
# 1      is a y o old female who has a past medical hi...
# 2      is a y o old female with aids p w cough and o...
# 3      is a y o old female with hx of anxiety asthma...
# 4      is a y o old female with pmh of gastritis and...
# ...                                                 ...
# 3979   is a y o old female with lupus cystitis s p r...
# 3980   is a y o old female with pmh ulcerative colit...
# 3981   is a y o old female with a pmh w lupus c b re...
# 3982   is a y o old female with seizure disorder and...
# 3983   is a y o old male with cervical myeloradiculo...
#
# [3984 rows x 46 columns]

# %%
def clean_medical_summary(text):
    # Remove newline characters
    cleaned = text.replace('\n', ' ').replace('\r', ' ')
    
    # Strip extra spaces
    cleaned = ' '.join(cleaned.split())
    
    return cleaned
df4["Assistant_Content"] = df4["Assistant_Content"].apply(clean_medical_summary)

# %%
df4["Assistant_Content"][4]
# Out:
# '26 y.o. female, with h/o G1P1, previous normal labor and delivery, epidural, 2nd degree perineal laceration, postpartum course: normal, no pending tests or complications, and currently presenting with vaginal bleeding.'

# %%
# Define a function to process text (for example, to make it lowercase and clean non-alpha-numeric characters)
def process_text(text):
    # Ensure the text is a string, handle NaN or invalid data by converting it to a string or empty string
    if not isinstance(text, str):
        text = str(text)  # Convert to string if it's not a string (e.g., for float or NaN values)
    
    # Convert everything to lowercase.
    text = text.lower()
    
    # Replace any non-alpha-numeric characters with spaces.
    text = re.sub(r"[^a-z0-9]+", " ", six.ensure_str(text))
    
    return text

# Example usage: Process text columns in your DataFrame
df['Processed_One_Sentence_Extracted'] = df['One_Sentence_Extracted'].apply(process_text)
df['Processed_Generated_Summary'] = df['Generated_Summary'].apply(process_text)

# Similarly, you can process text in df2 or any other DataFrame
df2['Processed_One_Sentence_Extracted'] = df2['One_Sentence_Extracted'].apply(process_text)
df2['Processed_Generated_Summary'] = df2['Generated_Summary'].apply(process_text)

# Similarly, you can process text in df2 or any other DataFrame
df3['Processed_One_Sentence_Extracted'] = df3['One_Sentence_Extracted'].apply(process_text)
df3['Processed_Generated_Summary'] = df3['Generated_Summary'].apply(process_text)


# Similarly, you can process text in df2 or any other DataFrame
df4['Processed_One_Sentence_Extracted'] = df4['Processed_One_Sentence_Extracted'].apply(process_text)
df4['Processed_Generated_Summary'] = df4['Assistant_Content'].apply(process_text)

# %%
len(df)
# Out:
# 3984

# %%
len(df2)
# Out:
# 3984

# %%
len(df3)
# Out:
# 3984

# %%
len(df4)
# Out:
# 3984

# %%
# Define function to compute ROUGE scores and F1 scores
def compute_rouge_scores(reference, hypothesis):
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    scores = scorer.score(reference, hypothesis)
    
    # Extract ROUGE scores
    rouge1_precision = scores['rouge1'].precision
    rouge1_recall = scores['rouge1'].recall
    rouge1_fmeasure = scores['rouge1'].fmeasure
    
    rouge2_precision = scores['rouge2'].precision
    rouge2_recall = scores['rouge2'].recall
    rouge2_fmeasure = scores['rouge2'].fmeasure
    
    rougeL_precision = scores['rougeL'].precision
    rougeL_recall = scores['rougeL'].recall
    rougeL_fmeasure = scores['rougeL'].fmeasure
    
    # Calculate F1 for each ROUGE score
    f1_rouge1 = 2 * (rouge1_precision * rouge1_recall) / (rouge1_precision + rouge1_recall) if (rouge1_precision + rouge1_recall) != 0 else 0
    f1_rouge2 = 2 * (rouge2_precision * rouge2_recall) / (rouge2_precision + rouge2_recall) if (rouge2_precision + rouge2_recall) != 0 else 0
    f1_rougeL = 2 * (rougeL_precision * rougeL_recall) / (rougeL_precision + rougeL_recall) if (rougeL_precision + rougeL_recall) != 0 else 0
    
    # Return ROUGE F1 scores for the DataFrame
    return pd.Series([rouge1_fmeasure, rouge2_fmeasure, rougeL_fmeasure, f1_rouge1, f1_rouge2, f1_rougeL], 
                     index=['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'ROUGE-1-F1', 'ROUGE-2-F1', 'ROUGE-L-F1'])



# Compute ROUGE scores for df using processed columns
df[['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'ROUGE-1-F1', 'ROUGE-2-F1', 'ROUGE-L-F1']] = df.apply(
    lambda row: compute_rouge_scores(row['Processed_One_Sentence_Extracted'], row['Processed_Generated_Summary']),
    axis=1
)

# Compute ROUGE scores for df2 using processed columns
df2[['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'ROUGE-1-F1', 'ROUGE-2-F1', 'ROUGE-L-F1']] = df2.apply(
    lambda row: compute_rouge_scores(row['Processed_One_Sentence_Extracted'], row['Processed_Generated_Summary']),
    axis=1
)

# Compute ROUGE scores for df2 using processed columns
df3[['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'ROUGE-1-F1', 'ROUGE-2-F1', 'ROUGE-L-F1']] = df3.apply(
    lambda row: compute_rouge_scores(row['Processed_One_Sentence_Extracted'], row['Processed_Generated_Summary']),
    axis=1
)

# Compute ROUGE scores for df2 using processed columns
df4[['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'ROUGE-1-F1', 'ROUGE-2-F1', 'ROUGE-L-F1']] = df4.apply(
    lambda row: compute_rouge_scores(row['Processed_One_Sentence_Extracted'], row['Assistant_Content']),
    axis=1
)

# Compute the aggregated (mean) ROUGE scores and F1 scores for df
aggregated_rouge_f1_scores_df = df[['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'ROUGE-1-F1', 'ROUGE-2-F1', 'ROUGE-L-F1']].mean()

# Compute the aggregated (mean) ROUGE scores and F1 scores for df2
aggregated_rouge_f1_scores_df2 = df2[['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'ROUGE-1-F1', 'ROUGE-2-F1', 'ROUGE-L-F1']].mean()

# Compute the aggregated (mean) ROUGE scores and F1 scores for df2
aggregated_rouge_f1_scores_df3 = df3[['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'ROUGE-1-F1', 'ROUGE-2-F1', 'ROUGE-L-F1']].mean()

# Compute the aggregated (mean) ROUGE scores and F1 scores for df2
aggregated_rouge_f1_scores_df4 = df4[['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'ROUGE-1-F1', 'ROUGE-2-F1', 'ROUGE-L-F1']].mean()

# Print the aggregated scores for df
print(f'Aggregated ROUGE and F1 Scores for GPT-4o:\n{aggregated_rouge_f1_scores_df}')

# Print the aggregated scores for df2
print(f'Aggregated ROUGE and F1 Scores for GPT-3.5:\n{aggregated_rouge_f1_scores_df2}')


# Print the aggregated scores for df2
print(f'Aggregated ROUGE and F1 Scores for O3-mini:\n{aggregated_rouge_f1_scores_df3}')


# Print the aggregated scores for df2
print(f'Aggregated ROUGE and F1 Scores for LLama3:\n{aggregated_rouge_f1_scores_df4}')
# Out:
# Aggregated ROUGE and F1 Scores for GPT-4o:
# ROUGE-1       0.346749
# ROUGE-2       0.126664
# ROUGE-L       0.285771
# ROUGE-1-F1    0.346749
# ROUGE-2-F1    0.126664
# ROUGE-L-F1    0.285771
# dtype: float64
# Aggregated ROUGE and F1 Scores for GPT-3.5:
# ROUGE-1       0.309570
# ROUGE-2       0.131968
# ROUGE-L       0.262131
# ROUGE-1-F1    0.309570
# ROUGE-2-F1    0.131968
# ROUGE-L-F1    0.262131
# dtype: float64
# Aggregated ROUGE and F1 Scores for O3-mini:
# ROUGE-1       0.311885
# ROUGE-2       0.120407
# ROUGE-L       0.271613
# ROUGE-1-F1    0.311885
# ROUGE-2-F1    0.120407
# ROUGE-L-F1    0.271613
# dtype: float64
# Aggregated ROUGE and F1 Scores for LLama3:
# ROUGE-1       0.293899
# ROUGE-2       0.110161
# ROUGE-L       0.250804
# ROUGE-1-F1    0.293899
# ROUGE-2-F1    0.110161
# ROUGE-L-F1    0.250804
# dtype: float64
