# %%
### disposition experiment for gpt 3.5

# %%
import pandas as pd
pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_colwidth', None)  # Set max column width to None
pd.set_option('display.width', None)  # Set width to None

# %%
df = pd.read_csv('results.csv')

# %%
import re
def extract_until_medical_decision(text):
    if pd.isna(text):
        return None
    # Split at first occurrence of "Medical Decision" (case-insensitive)
    parts = re.split(r'\bMedical Decision\b', text, flags=re.IGNORECASE)
    return parts[0].strip() if parts else None

# Apply it to the column
df['ED_Presentations'] = df['ED_Provider_Notes_Text'].apply(extract_until_medical_decision)

# %%
import pandas as pd
import os
import re
import json
import base64
import requests
import time
import urllib.parse

pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_colwidth', None)  # Set max column width to None
pd.set_option('display.width', None)  # Set width to None
# First, let's test by hard coding your Mulesoft Azure API key into the next line
API_KEY = 'MTEwMTQzZjI4MzBjNDY0MTgyMjUyMWE3MDAyZjQ4MTM6OGI3YUQzMDE1QTk0NDVmNDk3ZDNBYTVGOERGNjJFNDk='  ##### Paste your API key between the quotes #####
API_VERSION = '2024-06-01'  # For the most recent production release: https://learn.microsoft.com/en-us/azure/ai-services/openai/api-version-deprecation#latest-ga-api-release
RESOURCE_ENDPOINT = 'https://unified-api.ucsf.edu/general'  # no trailing slash--this is used by libraries as a partial URL
DEPLOYMENT_NAME = "gpt-35-turbo-16k"

# %%
def predict_disposition_with_dynamic_notes(row):
    # Extract all available fields
    chief_complaint = row['primarychiefcomplaintname']
    sex = row['sex']
    age = row['Age']
    presentation = row['ED_Presentations']
    
    # Check if necessary basic fields exist
    if pd.isna(chief_complaint):
        return None, None  # Skip if chief complaint is missing, return None for both prediction and requested notes
    
    # Initialize available note types with their existence status
    available_notes = {
        'Discharge Summary': not pd.isna(row.get('Discharge_Summary_Text')),
        'Progress Notes': not pd.isna(row.get('Progress_Note_Text')),
        'H&P': not pd.isna(row.get('HP_Note_Text')),
        'Echo': not pd.isna(row.get('Echo_Text')),
        'Imaging': not pd.isna(row.get('Imaging_Text')),
        'Consult': not pd.isna(row.get('Consult_Text')),
        'ECG': not pd.isna(row.get('ECG_Text')),
    }
    
    # Step 1: Ask the model which notes it wants to see (always include Discharge Summary if available)
    url = f"{RESOURCE_ENDPOINT}/openai/deployments/{DEPLOYMENT_NAME}/chat/completions?api-version={API_VERSION}"
    
    headers = {
        "Content-Type": "application/json",
        "api-key": API_KEY
    }
    
    # First message to decide which notes to read
    selection_payload = {
        "messages": [
            {"role": "system", "content": "You are an experienced Emergency Department (ED) physician. Your task is to decide which medical notes you need to read to predict the patient's ED disposition based on the chief complaint, PMH, physical exam findings, age, and sex."},
            {"role": "user", "content": f"Patient basic info: {age}yo {sex} with chief complaint: {chief_complaint}\n\n"
                                      f"Available notes (respond ONLY with the names of notes you want to see, separated by commas):\n"
                                      f"- Discharge Summary: {'Available' if available_notes['Discharge Summary'] else 'Not available'}\n"
                                      f"- Progress Notes: {'Available' if available_notes['Progress Notes'] else 'Not available'}\n"
                                      f"- H&P: {'Available' if available_notes['H&P'] else 'Not available'}\n"
                                      f"- Echo: {'Available' if available_notes['Echo'] else 'Not available'}\n"
                                      f"- Imaging: {'Available' if available_notes['Imaging'] else 'Not available'}\n"
                                      f"- Consult: {'Available' if available_notes['Consult'] else 'Not available'}\n"
                                      f"- ECG: {'Available' if available_notes['ECG'] else 'Not available'}\n"
                                      f"Based on the chief complaint, list ONLY the note types you need to review (comma-separated, no explanation). Always include Discharge Summary if available:"}
        ],
        "temperature": 0.1,
        "max_tokens": 1000
    }
    
    # Request note selection with improved rate limit handling
    retries = 0
    requested_notes = []
    notes_requested_str = ""  # String to track requested notes
    max_retries = 5  # Increased retry attempts
    
    while retries < max_retries:
        try:
            # Exponential backoff with jitter for rate limiting
            if retries > 0:
                # Calculate delay with exponential backoff and random jitter
                delay = (2 ** retries) + (random.random() * 2)
                print(f"Selection request: Backing off for {delay:.2f} seconds before retry {retries+1}/{max_retries}...")
                time.sleep(delay)
            
            selection_response = requests.post(url, headers=headers, json=selection_payload)
            
            # Handle rate limiting specifically
            if selection_response.status_code == 429:  # Too Many Requests
                retry_after = int(selection_response.headers.get('Retry-After', 60))
                print(f"Rate limited. Waiting {retry_after} seconds as instructed by API...")
                time.sleep(retry_after)
                retries += 1
                continue
                
            selection_response.raise_for_status()
            
            # Get requested note types
            notes_text = selection_response.json()["choices"][0]["message"]["content"].strip()
            requested_notes = [note.strip() for note in notes_text.split(',')]
            
            # Save the original request for the tracking column
            notes_requested_str = notes_text
            
            # Filter out unavailable notes
            requested_notes = [note for note in requested_notes 
                              if note in available_notes.keys() and available_notes[note]]
            
            # Always include Discharge Summary if available and not already requested
            if available_notes['Discharge Summary'] and 'Discharge Summary' not in requested_notes:
                requested_notes.append('Discharge Summary')
                if notes_requested_str:
                    notes_requested_str += ", Discharge Summary (auto-added)"
                else:
                    notes_requested_str = "Discharge Summary (auto-added)"
            
            break
        except requests.exceptions.RequestException as e:
            print(f"Note selection request failed: {e}. Retrying {retries+1}/{max_retries}...")
            retries += 1
    
    if not requested_notes and available_notes['Discharge Summary']:
        # Default to discharge summary if selection failed but it's available
        requested_notes = ['Discharge Summary']
        notes_requested_str = "Failed to get selections. Defaulted to: Discharge Summary"
    elif not requested_notes:
        # If selection failed and no discharge summary, use whatever is available
        available_notes_list = [note for note, available in available_notes.items() if available][:2]
        requested_notes = available_notes_list
        notes_requested_str = f"Failed to get selections. Defaulted to: {', '.join(available_notes_list)}"
    
    # Step 2: Prepare the actual notes content
    notes_content = ""
    
    # Map note types to DataFrame column names
    note_type_to_column = {
        'Discharge Summary': 'Discharge_Summary_Text',
        'Progress Notes': 'Progress_Note_Text',
        'H&P': 'HP_Note_Text',
        'Echo': 'Echo_Text',
        'Imaging': 'Imaging_Text',
        'Consult': 'Consult_Text',
        'ECG': 'ECG_Text',
    }
    
    # Function to truncate text to manage token limits
    def truncate_text(text, max_chars=3000):
        if text and len(text) > max_chars:
            return text[:max_chars] + "..."
        return text
    
    # Add requested notes to content, with truncation
    for note_type in requested_notes:
        column_name = note_type_to_column.get(note_type)
        if column_name and not pd.isna(row.get(column_name)):
            notes_content += f"\n\n{note_type}:\n{truncate_text(row[column_name])}"
    
    # Step 3: Generate the disposition prediction
    prediction_payload = {
        "messages": [
            {"role": "system", "content": "You are an experienced Emergency Department (ED) physician tasked with predicting the most likely disposition for a patient based on their presentation and physicial, chief complaint, and available past medical information."},
            {"role": "user", "content": f"Based on the patient's chief complaint, age, sex, and available clinical information, predict the most likely ED disposition from the following choices: 'Discharge', 'Admit', 'Eloped', 'Transfer to Another Facility', 'AMA', 'OR Admit', 'LWBS after Triage', 'Send to L&D', 'Expired','Dismissed - Never Arrived', 'Observation', 'None'-- ONLY RESPOND WITH THESE OPTIONS, no explanations.\n\n"
                                      f"Chief Complaint: {chief_complaint}\n"
                                      f"Age: {age}\n"
                                      f"Sex: {sex}\n"
                                      f"Current ED Presentation: {presentation}\n"
                                      f"{notes_content}"}
        ],
        "temperature": 0.1,
        "max_tokens": 4096
    }
    
    # Request the disposition prediction with improved rate limit handling
    retries = 0
    max_retries = 5  # Increased retry attempts
    
    while retries < max_retries:
        try:
            # Exponential backoff with jitter for rate limiting
            if retries > 0:
                # Calculate delay with exponential backoff and random jitter
                delay = (2 ** retries) + (random.random() * 2)
                print(f"Prediction request: Backing off for {delay:.2f} seconds before retry {retries+1}/{max_retries}...")
                time.sleep(delay)
            
            prediction_response = requests.post(url, headers=headers, json=prediction_payload)
            
            # Handle rate limiting specifically
            if prediction_response.status_code == 429:  # Too Many Requests
                retry_after = int(prediction_response.headers.get('Retry-After', 60))
                print(f"Rate limited. Waiting {retry_after} seconds as instructed by API...")
                time.sleep(retry_after)
                retries += 1
                continue
                
            prediction_response.raise_for_status()
            return prediction_response.json()["choices"][0]["message"]["content"].strip(), notes_requested_str
            
        except requests.exceptions.RequestException as e:
            print(f"Prediction request failed: {e}. Retrying {retries+1}/{max_retries}...")
            retries += 1
    
    return None, notes_requested_str  # Return None for prediction and the requested notes string if all retries fail

# Import required additional libraries
import time
import random

# Process in batches with rate limit handling
def process_in_batches(df, batch_size=10, pause_between_batches=30):
    all_predictions = []
    all_requested_notes = []
    total_rows = len(df)
    
    # Create backup file path with timestamp
    import datetime
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    backup_path = f"ed_disposition_backup_{timestamp}.csv"
    
    for i in range(0, total_rows, batch_size):
        print(f"Processing batch {i//batch_size + 1} of {(total_rows-1)//batch_size + 1}...")
        
        # Process one batch
        end_idx = min(i + batch_size, total_rows)
        batch_df = df.iloc[i:end_idx]
        
        # Apply function to batch and collect results
        batch_results = batch_df.apply(lambda row: predict_disposition_with_dynamic_notes(row), axis=1)
        
        # Unpack results into separate lists
        batch_predictions = [result[0] for result in batch_results]
        batch_requested_notes = [result[1] for result in batch_results]
        
        # Add to overall results
        all_predictions.extend(batch_predictions)
        all_requested_notes.extend(batch_requested_notes)
        
        # Save progress after each batch
        temp_df = df.copy()
        
        # Create lists with proper length
        full_predictions = all_predictions + [None] * (total_rows - len(all_predictions))
        full_requested_notes = all_requested_notes + [None] * (total_rows - len(all_requested_notes))
        
        # Fill in results we have so far
        temp_df["Predicted_Disposition"] = full_predictions
        temp_df["Requested_Notes"] = full_requested_notes
        
        # Save backup
        temp_df.to_csv(backup_path, index=False)
        print(f"Progress saved to {backup_path}")
        
        # Pause between batches to avoid rate limits (unless it's the last batch)
        if end_idx < total_rows:
            print(f"Pausing for {pause_between_batches} seconds to avoid rate limits...")
            time.sleep(pause_between_batches)
    
    # Return results as a list of tuples to match the expected format
    return list(zip(all_predictions, all_requested_notes))

# Apply batch processing instead of processing all rows at once
results = process_in_batches(df, batch_size=5, pause_between_batches=60)

# Split the results into two columns
df["Predicted_Disposition"] = [result[0] for result in results]
df["Requested_Notes"] = [result[1] for result in results]

# Add column to track accuracy of prediction if we have the actual disposition column
if "eddisposition" in df.columns:
    df["Prediction_Correct"] = df["Predicted_Disposition"] == df["eddisposition"]
    
    # Calculate overall accuracy
    accuracy = (df["Prediction_Correct"].sum() / df["Prediction_Correct"].count()) * 100
    print(f"Overall disposition prediction accuracy: {accuracy:.2f}%")
    
    # Breakdown by disposition type
    disposition_accuracy = df.groupby("eddisposition").agg(
        total_count=("eddisposition", "count"),
        correct_predictions=("Prediction_Correct", "sum")
    )
    
    # Calculate percentage accuracy for each disposition type
    disposition_accuracy["accuracy_pct"] = (
        disposition_accuracy["correct_predictions"] / 
        disposition_accuracy["total_count"] * 100
    )
    
    # Show top dispositions by count with accuracy
    print("\nDispositions by frequency with accuracy:")
    print(disposition_accuracy.sort_values("total_count", ascending=False))

# Save to CSV and Display
df.to_csv("35_ed_dispo_predictions.csv", index=False)
print("Results saved to 35_ed_dispo_predictions.csv")
# Out:
# Processing batch 1 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 2 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 3 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 4 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 5 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 6 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 7 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 8 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 9 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 10 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 11 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 12 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 13 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 14 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 15 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 16 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 17 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 18 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 19 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 20 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 21 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 22 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 23 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 24 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 25 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 26 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 27 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 28 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 29 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 30 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 31 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 32 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 33 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 34 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 35 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 36 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 37 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 38 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 39 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 40 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 41 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 42 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 43 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 44 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 45 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 46 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 47 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 48 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 49 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 50 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 51 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 52 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 53 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 54 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 55 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 56 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 57 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 58 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 59 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 60 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 61 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 62 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 63 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 64 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 65 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 66 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 67 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 68 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 69 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 70 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 71 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 72 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 73 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 74 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 75 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 76 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 77 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 78 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 79 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 80 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 81 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 82 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 83 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 84 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 85 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 86 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 87 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 88 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 89 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 90 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 91 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 92 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 93 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 94 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 95 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 96 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 97 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 98 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 99 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 100 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 101 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 102 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 103 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 104 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 105 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 106 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 107 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 108 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 109 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 110 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 111 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 112 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 113 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 114 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 115 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 116 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 117 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 118 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 119 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 120 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 121 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 122 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 123 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 124 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 125 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 126 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 127 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 128 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 129 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 130 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 131 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 132 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 133 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 134 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 135 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 136 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 137 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 138 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 139 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 140 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 141 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 142 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 143 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 144 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 145 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 146 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 147 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 148 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 149 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 150 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 151 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 152 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 153 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 154 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 155 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 156 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 157 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 158 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 159 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 160 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 161 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 162 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 163 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 164 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 165 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 166 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 167 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 168 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 169 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 170 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 171 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 172 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 173 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 174 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 175 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 176 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 177 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 178 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 179 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 180 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 181 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 182 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 183 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 184 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 185 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 186 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 187 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 188 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 189 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 190 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 191 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 192 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 193 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 194 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 195 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 196 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 197 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 198 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 199 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 200 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 201 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 202 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 203 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 204 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 205 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 206 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 207 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 208 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 209 of 797...
# Note selection request failed: 401 Client Error: PermissionDenied for url: https://unified-api.ucsf.edu/general/openai/deployments/gpt-35-turbo-16k/chat/completions?api-version=2024-06-01. Retrying 1/5...
# Selection request: Backing off for 2.18 seconds before retry 2/5...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 210 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 211 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 212 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 213 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 214 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 215 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 216 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 217 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 218 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 219 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 220 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 221 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 222 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 223 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 224 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 225 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 226 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 227 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 228 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 229 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 230 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 231 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 232 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 233 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 234 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 235 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 236 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 237 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 238 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 239 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 240 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 241 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 242 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 243 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 244 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 245 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 246 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 247 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 248 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 249 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 250 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 251 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 252 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 253 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 254 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 255 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 256 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 257 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 258 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 259 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 260 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 261 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 262 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 263 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 264 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 265 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 266 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 267 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 268 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 269 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 270 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 271 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 272 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 273 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 274 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 275 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 276 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 277 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 278 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 279 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 280 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 281 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 282 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 283 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 284 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 285 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 286 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 287 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 288 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 289 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 290 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 291 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 292 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 293 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 294 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 295 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 296 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 297 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 298 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 299 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 300 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 301 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 302 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 303 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 304 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 305 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 306 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 307 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 308 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 309 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 310 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 311 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 312 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 313 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 314 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 315 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 316 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 317 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 318 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 319 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 320 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 321 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 322 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 323 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 324 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 325 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 326 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 327 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 328 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 329 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 330 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 331 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 332 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 333 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 334 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 335 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 336 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 337 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 338 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 339 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 340 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 341 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 342 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 343 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 344 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 345 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 346 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 347 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 348 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 349 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 350 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 351 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 352 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 353 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 354 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 355 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 356 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 357 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 358 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 359 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 360 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 361 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 362 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 363 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 364 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 365 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 366 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 367 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 368 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 369 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 370 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 371 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 372 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 373 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 374 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 375 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 376 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 377 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 378 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 379 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 380 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 381 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 382 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 383 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 384 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 385 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 386 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 387 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 388 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 389 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 390 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 391 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 392 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 393 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 394 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 395 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 396 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 397 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 398 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 399 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 400 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 401 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 402 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 403 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 404 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 405 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 406 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 407 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 408 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 409 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 410 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 411 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 412 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 413 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 414 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 415 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 416 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 417 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 418 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 419 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 420 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 421 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 422 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 423 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 424 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 425 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 426 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 427 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 428 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 429 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 430 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 431 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 432 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...
# Processing batch 433 of 797...
# Progress saved to ed_disposition_backup_20250430_170031.csv
# Pausing for 60 seconds to avoid rate limits...

# %%
import pandas as pd
results = pd.read_csv('35_ed_dispo_predictions.csv')

# %%
results.shape
# Out:
# (3984, 49)

# %%
# Add column to track accuracy of disposition prediction
results["Prediction_Correct"] = results["Predicted_Disposition"] == results["eddisposition"]

# Calculate overall accuracy
accuracy = (results["Prediction_Correct"].sum() / results["Prediction_Correct"].count()) * 100
print(f"Overall disposition prediction accuracy: {accuracy:.2f}%")
# Out:
# Overall disposition prediction accuracy: 57.08%
